# %% [markdown]
# # RAN Knowledge Graph Builder
# This notebook demonstrates step-by-step execution of knowledge graph generation using the `kg_builder.py` module.
#
# ## Overview
# The knowledge graph builder transforms RAN configuration data into a structured Neo4j graph database with:
# - **Nodes**: Tables, Columns, Concepts
# - **Relationships**: NAME_SIMILARITY, VALUE_OVERLAP, PATTERN_MATCH, REFERENCES, CONCEPTUAL_GROUP
#
# ## Prerequisites
# - Neo4j database running on localhost:7687
# - Required Python packages installed
# - Sample RAN data available

# %%
# Import required libraries
import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Import our knowledge graph builder
from kg_builder import RANNeo4jIntegrator
import pathlib
notebook_dir = pathlib.Path().resolve()
parser_dir = notebook_dir / '../parser_module'
sys.path.append(str(parser_dir.resolve()))
from parser import parse_xml

print("✅ Libraries imported successfully!")
# Out:
# ✅ Libraries imported successfully!

# %%
# Step 1: Collect Data
xml_file_path = '../parser_module/data/RAN_CM_DATA_SAMPLES.xml'
dfs, metadata, metadata2 = parse_xml(xml_file_path)

# Display sample data info
print("\n📋 Data Overview:")
for table_name, df in dfs.items():
    print(f"  • {table_name}: {len(df)} rows, {len(df.columns)} columns")
    print(f"    Columns: {list(df.columns)}")
    print()
# Out:
# 📋 Data Overview:
#   • MeContext: 2 rows, 7 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'vsDataType', 'vsDataFormatVersion', 'MeContextId', 'neType']
#
#   • EnodeBInfo: 2 rows, 5 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'userLabel']
#
#   • AnrFunction: 4 rows, 48 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'AnrFunction.removeGnbTime', 'AnrFunction.removeEnbTime', 'AnrFunction.anrFunctionId', 'AnrFunction.removeFreqRelTime', 'AnrFunction.removeNrelTime', 'AnrFunction.pciConflictMobilityEcgiMeas', 'AnrFunction.plmnWhiteListUtranEnabled', 'AnrFunction.zzzTemporary13', 'AnrFunction.probCellDetectLowHoSuccTime', 'AnrFunction.zzzTemporary12', 'AnrFunction.zzzTemporary7', 'AnrFunction.zzzTemporary11', 'AnrFunction.zzzTemporary10', 'AnrFunction.zzzTemporary9', 'AnrFunction.removeNcellTime', 'AnrFunction.perCgiMeasPlmnWhiteListUtran', 'AnrFunction.prioHoSuccRate', 'AnrFunction.perCgiMeasPlmnWhiteListGeran', 'AnrFunction.maxTimeEventBasedPciConf', 'AnrFunction.cellRelHoAttRateThreshold', 'AnrFunction.pciConflictDetectionEcgiMeas', 'AnrFunction.probCellDetectMedHoSuccThres', 'AnrFunction.removeNgnbTime', 'AnrFunction.prioHoRate', 'AnrFunction.perEcgiMeasPlmnWhiteList', 'AnrFunction.plmnWhiteListEnabled', 'AnrFunction.probCellDetectLowHoSuccThres', 'AnrFunction.s1HoPrepConsFailThres', 'AnrFunction.detectObsoleteExtCellsEnabled', 'AnrFunction.prioTime', 'AnrFunction.zzzTemporary1', 'AnrFunction.removeNenbTime', 'AnrFunction.zzzTemporary2', 'AnrFunction.zzzTemporary3', 'AnrFunction.zzzTemporary4', 'AnrFunction.zzzTemporary5', 'AnrFunction.zzzTemporary6', 'AnrFunction.plmnWhiteListGeranEnabled', 'AnrFunction.problematicCellPolicy', 'AnrFunction.probCellDetectMedHoSuccTime', 'AnrFunction.maxNoPciReportsEvent']
#
#   • TermPointToGNBDU: 2 rows, 13 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'TermPointToGNBDU.usedIpAddress', 'TermPointToGNBDU.gNBDUId', 'TermPointToGNBDU.operationalState', 'TermPointToGNBDU.availabilityStatus', 'TermPointToGNBDU.gNBDUName', 'TermPointToGNBDU.termPointToGNBDUId']
#
#   • Mcpc: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'Mcpc.mcpcId']
#
#   • UeMC: 2 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'UeMC.userLabel', 'UeMC.ueMCId', 'UeMC.freqSelAtBlindRwrToEutran']
#
#   • Mcfb: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'Mcfb.voiceEpsFbPossible', 'Mcfb.mcfbId']
#
#   • TrafficSteering: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'TrafficSteering.userLabel', 'TrafficSteering.trafficSteeringId']
#
#   • EndpointResource: 6 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'EndpointResource.endpointResourceId', 'EndpointResource.userLabel', 'EndpointResource.reservedBy']
#
#   • IntraFreqMC: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'IntraFreqMC.intraFreqMCId']
#
#   • NrdcSnTermination: 2 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NrdcSnTermination.reservedBy', 'NrdcSnTermination.defaultNrdcSnTerm', 'NrdcSnTermination.nrdcSnTerminationId']
#
#   • NRCellCU: 6 rows, 50 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NRCellCU.transmitSib2', 'NRCellCU.userLabel', 'NRCellCU.threshServingLowP', 'NRCellCU.threshServingLowQ', 'NRCellCU.sNonIntraSearchP', 'NRCellCU.sNonIntraSearchQ', 'NRCellCU.primaryPLMNId', 'NRCellCU.pmUeIntraFreqEnabled', 'NRCellCU.cellLocalId', 'NRCellCU.nRCellCUId', 'NRCellCU.tHystNormal', 'NRCellCU.transmitSib5', 'NRCellCU.qHystSfMedium', 'NRCellCU.cellState', 'NRCellCU.tEvaluation', 'NRCellCU.transmitSib4', 'NRCellCU.serviceState', 'NRCellCU.nrdcMnCellProfileRef', 'NRCellCU.nCellChangeMedium', 'NRCellCU.trStSaCellProfileRef', 'NRCellCU.mcpcPSCellProfileRef', 'NRCellCU.sNSSAIList', 'NRCellCU.mdtEnabled', 'NRCellCU.nCI', 'NRCellCU.hiPrioDetEnabled', 'NRCellCU.pwsEmergencyAreaIdList', 'NRCellCU.mcpcPSCellEnabled', 'NRCellCU.qHyst', 'NRCellCU.nRTAC', 'NRCellCU.nRFrequencyRef', 'NRCellCU.nCellChangeHigh', 'NRCellCU.mcfbCellProfileRef', 'NRCellCU.ueMCCellProfileRef', 'NRCellCU.mdtCellProfileRef', 'NRCellCU.pmUeIntraFreqCellProfileRef', 'NRCellCU.mcpcPCellProfileRef', 'NRCellCU.intraFreqMCCellProfileRef', 'NRCellCU.qHystSfHigh', 'NRCellCU.reservedBy', 'NRCellCU.pSCellCapable', 'NRCellCU.trStPSCellProfileRef', 'NRCellCU.pLMNIdList', 'NRCellCU.mcpcPCellEnabled']
#
#   • UeCC: 4 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'UeCC.ueCCId']
#
#   • SecurityHandling: 4 rows, 15 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'SecurityHandling.integrityProtectAlgoPrio', 'SecurityHandling.personalDataProtectionEnabled', 'SecurityHandling.securityHandlingId', 'SecurityHandling.cipheringAlgoPrio', 'SecurityHandling.integProtUserPlaneLowRate', 'SecurityHandling.featCtrlIntegProtUserPlane', 'SecurityHandling.rbIdSupervisionActive', 'SecurityHandling.countWrapSupervisionActive']
#
#   • NrdcControl: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NrdcControl.nrdcControlId']
#
#   • EUtraNetwork: 4 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'EUtraNetwork.userLabel', 'EUtraNetwork.eUtraNetworkId']
#
#   • NRNetwork: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NRNetwork.nRNetworkId', 'NRNetwork.simpleNRFreqSmtc']
#
#   • QciProfileEndcConfigExt: 2 rows, 11 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'QciProfileEndcConfigExt.qciProfileEndcConfigExtId', 'QciProfileEndcConfigExt.initialUplinkConf', 'QciProfileEndcConfigExt.ulDataSplitThreshold', 'QciProfileEndcConfigExt.ulDataSplitThresholdMcg']
#
#   • Mdt: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'Mdt.userLabel', 'Mdt.mdtId']
#
#   • ExternalPower: 2 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ExternalPower.availabilityStatus', 'ExternalPower.operationalState', 'ExternalPower.externalPowerId']
#
#   • FieldReplaceableUnit: 11 rows, 19 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'FieldReplaceableUnit.hwTestResult', 'FieldReplaceableUnit.userLabel', 'FieldReplaceableUnit.positionRef', 'FieldReplaceableUnit.positionInformation', 'FieldReplaceableUnit.floorInformation', 'FieldReplaceableUnit.administrativeState', 'FieldReplaceableUnit.positionCoordinates', 'FieldReplaceableUnit.supportUnitRef', 'FieldReplaceableUnit.fieldReplaceableUnitId', 'FieldReplaceableUnit.productData', 'FieldReplaceableUnit.isSharedWithExternalMe', 'FieldReplaceableUnit.operationalState']
#
#   • RiLink: 9 rows, 15 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'RiLink.fronthaulDeviceLineRate', 'RiLink.riLinkId', 'RiLink.transportType', 'RiLink.operationalState', 'RiLink.availabilityStatus', 'RiLink.linkTag', 'RiLink.riPortRef2', 'RiLink.riPortRef1']
#
#   • SupportUnit: 2 rows, 14 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'SupportUnit.commandResult', 'SupportUnit.supportUnitId', 'SupportUnit.administrativeState', 'SupportUnit.reservedBy', 'SupportUnit.productData', 'SupportUnit.operationalState', 'SupportUnit.providedServices']
#
#   • ServiceDiscoveryServer: 1 rows, 14 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ServiceDiscoveryServer.cluster', 'ServiceDiscoveryServer.gsdsStatus', 'ServiceDiscoveryServer.localAddress', 'ServiceDiscoveryServer.members', 'ServiceDiscoveryServer.nodeCredential', 'ServiceDiscoveryServer.trustCategory', 'ServiceDiscoveryServer.serviceDiscoveryServerId']
#
#   • CapacityUsage: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'CapacityUsage.capacityUsageId']
#
#   • RadioPowerOverbooking: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'RadioPowerOverbooking.radioPowerOverbookingId', 'RadioPowerOverbooking.featCtrlRadioPowerOverbooking']
#
#   • TimeSettings: 2 rows, 14 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'TimeSettings.gpsToUtcLeapSecondsChangeDate', 'TimeSettings.gpsToUtcLeapSeconds', 'TimeSettings.daylightSavingTimeStartDate', 'TimeSettings.daylightSavingTimeEndDate', 'TimeSettings.timeSettingsId', 'TimeSettings.timeOffset', 'TimeSettings.daylightSavingTimeOffset']
#
#   • ElementManagerWeb: 2 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ElementManagerWeb.idleTimer', 'ElementManagerWeb.elementManagerWebId', 'ElementManagerWeb.absoluteTimer']
#
#   • PmSupport: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PmSupport.pmSupportId', 'PmSupport.ropFileHandling']
#
#   • ExternalUpManager: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ExternalUpManager.externalUpManagerId']
#
#   • PowerSaving: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PowerSaving.bbPowerSavingsEnabled', 'PowerSaving.powerSavingId']
#
#   • CpriLinkSupervision: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'CpriLinkSupervision.cpriLinkFilterTime', 'CpriLinkSupervision.cpriLinkSupervisionId']
#
#   • OnSiteActivities: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'OnSiteActivities.technicianPresent', 'OnSiteActivities.onSiteActivitiesId']
#
#   • ServiceDiscovery: 1 rows, 15 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ServiceDiscovery.serviceDiscoveryId', 'ServiceDiscovery.localAddress', 'ServiceDiscovery.secondaryGsds', 'ServiceDiscovery.nodeCredential', 'ServiceDiscovery.primaryGsds', 'ServiceDiscovery.trustCategory', 'ServiceDiscovery.statusSecondary', 'ServiceDiscovery.statusPrimary']
#
#   • LicenseSupport: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'LicenseSupport.licenseSupportId', 'LicenseSupport.reportProgress']
#
#   • OamIpSupport: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'OamIpSupport.ipAddressChangeStatus', 'OamIpSupport.oamIpSupportId']
#
#   • AutoEsiM: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'AutoEsiM.userLabel', 'AutoEsiM.autoEsiMId']
#
#   • ConsumedEnergyMeasurement: 2 rows, 11 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ConsumedEnergyMeasurement.totalNumberOfUnits', 'ConsumedEnergyMeasurement.consumedEnergyMeasurementId', 'ConsumedEnergyMeasurement.reservedBy', 'ConsumedEnergyMeasurement.noOfContributingUnits']
#
#   • SectorEquipmentFunction: 9 rows, 20 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'SectorEquipmentFunction.userLabel', 'SectorEquipmentFunction.rfBranchRef', 'SectorEquipmentFunction.noiseFigure', 'SectorEquipmentFunction.sectorEquipmentFunctionId', 'SectorEquipmentFunction.nRFqBands', 'SectorEquipmentFunction.radioEquipmentOrdering', 'SectorEquipmentFunction.eUtranFqBands', 'SectorEquipmentFunction.administrativeState', 'SectorEquipmentFunction.reservedBy', 'SectorEquipmentFunction.availabilityStatus', 'SectorEquipmentFunction.operationalState', 'SectorEquipmentFunction.utranFddFqBands', 'SectorEquipmentFunction.geranFqBands']
#
#   • EquipmentDiscovery: 2 rows, 17 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'EquipmentDiscovery.sftpServerIpAddress', 'EquipmentDiscovery.sftpPassword', 'EquipmentDiscovery.portConfiguration', 'EquipmentDiscovery.equipmentDiscoveryStatus', 'EquipmentDiscovery.autoCreateAisgUnits', 'EquipmentDiscovery.sftpServerPath', 'EquipmentDiscovery.antennaDeviceScanInBackground', 'EquipmentDiscovery.equipmentDiscoveryId', 'EquipmentDiscovery.portVoltage', 'EquipmentDiscovery.sftpUsername']
#
#   • AutoProvisioning: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'AutoProvisioning.rbsConfigLevel', 'AutoProvisioning.autoProvisioningId']
#
#   • MpClusterHandling: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'MpClusterHandling.mpClusterHandlingId', 'MpClusterHandling.primaryCoreRef']
#
#   • TermPointToGNBCUCP: 2 rows, 15 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'TermPointToGNBCUCP.usedIpAddress', 'TermPointToGNBCUCP.ipv6Address', 'TermPointToGNBCUCP.administrativeState', 'TermPointToGNBCUCP.ipv4Address', 'TermPointToGNBCUCP.availabilityStatus', 'TermPointToGNBCUCP.operationalState', 'TermPointToGNBCUCP.termPointToGNBCUCPId', 'TermPointToGNBCUCP.gNBCUName']
#
#   • NRCellDU: 6 rows, 158 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NRCellDU.typeISinglePanelRiRestriction', 'NRCellDU.dftSOfdmPuschStartRsrpThresh', 'NRCellDU.ulAvailableCrbs', 'NRCellDU.ailgDlPrbLoadLevel', 'NRCellDU.drxOnDurationTimer', 'NRCellDU.pdcchOlaSelection', 'NRCellDU.trsResourceShifting', 'NRCellDU.ulStartCrb', 'NRCellDU.trsConfigMode', 'NRCellDU.endcDlNrQualHyst', 'NRCellDU.serviceState', 'NRCellDU.sfnOffset', 'NRCellDU.cellBarred', 'NRCellDU.sNSSAIList', 'NRCellDU.imsEmSupportEnabled', 'NRCellDU.networkSignalValue', 'NRCellDU.ailgBeamDirectionEnabled', 'NRCellDU.drxInactivityTimer', 'NRCellDU.maxUsersRachSchedPusch', 'NRCellDU.cellReservedForOperator', 'NRCellDU.ulRobustLaEnabled', 'NRCellDU.nRCellDUId', 'NRCellDU.drxEnable', 'NRCellDU.nrRrpEnabled', 'NRCellDU.dlRobustLaEnabled', 'NRCellDU.pointAArfcnTdd', 'NRCellDU.nrLteCoexistence', 'NRCellDU.maxNoOfAdvancedDlMuMimoLayers', 'NRCellDU.pdschRachBoost', 'NRCellDU.cbrsCellPriorityRank', 'NRCellDU.pZeroNomPuschGrant', 'NRCellDU.operationalState', 'NRCellDU.pwsBroadcastOngoing', 'NRCellDU.endcUlNrLowQualThresh', 'NRCellDU.pdcchRachBoost', 'NRCellDU.tddBorderVersion', 'NRCellDU.dlAvailableCrbs', 'NRCellDU.tddUlDlPattern', 'NRCellDU.rachPreambleTransMax', 'NRCellDU.ssbFrequencyAutoSelected', 'NRCellDU.csiRsConfig4P', 'NRCellDU.ssbGscn', 'NRCellDU.cbrsCellSsbControlEnabled', 'NRCellDU.fixWideBeamsForPeriodicSr', 'NRCellDU.nbIotCellDeployed', 'NRCellDU.pdschStartPrbStrategy', 'NRCellDU.endcDlNrLowQualThresh', 'NRCellDU.nCI', 'NRCellDU.nrSrsDlBufferVolThr', 'NRCellDU.ssbDurationAutoSelected', 'NRCellDU.pointAFrequencyTdd', 'NRCellDU.bfrEnabled', 'NRCellDU.dlStartCrb', 'NRCellDU.csiReportFormat', 'NRCellDU.rachPreambleRecTargetPower', 'NRCellDU.trsPeriodicity', 'NRCellDU.cellResourceMappingRef', 'NRCellDU.sibType2', 'NRCellDU.ulMaxMuMimoLayers', 'NRCellDU.csiRsShiftingSecondary', 'NRCellDU.sibType4', 'NRCellDU.nRTAC', 'NRCellDU.ssbOffsetAutoSelected', 'NRCellDU.sibType5', 'NRCellDU.ul256QamEnabled', 'NRCellDU.pointAFrequencyUlFdd', 'NRCellDU.dftSOfdmPuschEnabled', 'NRCellDU.csiRsConfig32P', 'NRCellDU.caSCellHandlingRef', 'NRCellDU.csiRsConfig16P', 'NRCellDU.drxLongCycle', 'NRCellDU.puschAllowedInDmrsSym', 'NRCellDU.dlChannelScramblingIdentity', 'NRCellDU.sibType6', 'NRCellDU.sibType7', 'NRCellDU.sibType8', 'NRCellDU.dl256QamEnabled', 'NRCellDU.pointAArfcnUlFdd', 'NRCellDU.srsHoppingBandwidth', 'NRCellDU.endcUlNrQualHyst', 'NRCellDU.pZeroNomSrs', 'NRCellDU.qRxLevMinOffset', 'NRCellDU.essMbsfnSubframeVariant', 'NRCellDU.trsModeSelected', 'NRCellDU.cellLocalId', 'NRCellDU.pdschAllowedInDmrsSym', 'NRCellDU.ulScSpillover', 'NRCellDU.ailgI11BeamDirection', 'NRCellDU.csiRsConfig2P', 'NRCellDU.ssbSubCarrierSpacing', 'NRCellDU.cellRange', 'NRCellDU.ssbOffset', 'NRCellDU.administrativeState', 'NRCellDU.ssbFrequency', 'NRCellDU.endcUlLegSwitchEnabled', 'NRCellDU.csiRsShiftingPrimary', 'NRCellDU.bandListManual', 'NRCellDU.pdcchLaSinrOffset', 'NRCellDU.siWindowLength', 'NRCellDU.nRSectorCarrierRef', 'NRCellDU.pZeroNomPucch', 'NRCellDU.covOptUlSchedFr2Enabled', 'NRCellDU.rachPreambleFormat', 'NRCellDU.additionalPucchForCaEnabled', 'NRCellDU.nRPCI', 'NRCellDU.dlScSpillover', 'NRCellDU.ailgModType', 'NRCellDU.qQualMinOffset', 'NRCellDU.dlMaxMuMimoLayers', 'NRCellDU.secondaryCellOnly', 'NRCellDU.cbrsCellBandwidthPreferred', 'NRCellDU.dlDmrsMuxSinrThresh', 'NRCellDU.drxProfileEnabled', 'NRCellDU.bandList', 'NRCellDU.ueBbProfileRef', 'NRCellDU.pLMNIdList', 'NRCellDU.ssbDuration', 'NRCellDU.puschStartPrbStrategy', 'NRCellDU.qQualMin', 'NRCellDU.advancedDlSuMimoEnabled', 'NRCellDU.subCarrierSpacing', 'NRCellDU.userLabel', 'NRCellDU.tddSpecialSlotPattern', 'NRCellDU.maxUeSpeed', 'NRCellDU.csiRsConfig8P', 'NRCellDU.cellState', 'NRCellDU.pointAFrequencyDlFdd', 'NRCellDU.trsPowerBoosting', 'NRCellDU.csiRsPeriodicity', 'NRCellDU.endcDlLegSwitchEnabled', 'NRCellDU.qRxLevMin', 'NRCellDU.cbrsCellPriority', 'NRCellDU.availabilityStatus', 'NRCellDU.csiRsActivePortConfi ...
#
#   • NRSynchronization: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NRSynchronization.nRSynchronizationId']
#
#   • NRSectorCarrier: 6 rows, 54 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NRSectorCarrier.ueAssistedPrecodingOptEnabled', 'NRSectorCarrier.altitude', 'NRSectorCarrier.pimAvoidDlMutingPeriod', 'NRSectorCarrier.noOfTxAntennas', 'NRSectorCarrier.sectorEquipmentFunctionRef', 'NRSectorCarrier.powerMeasAvgTime', 'NRSectorCarrier.noOfUsedTxAntennas', 'NRSectorCarrier.arfcnUL', 'NRSectorCarrier.latitude', 'NRSectorCarrier.essScLocalId', 'NRSectorCarrier.nRSectorCarrierId', 'NRSectorCarrier.rfBranchTxRef', 'NRSectorCarrier.txPowerPersistentLock', 'NRSectorCarrier.administrativeState', 'NRSectorCarrier.pimAvoidLevel', 'NRSectorCarrier.arfcnDL', 'NRSectorCarrier.txPowerChangeRate', 'NRSectorCarrier.availabilityStatus', 'NRSectorCarrier.scaledTransmissionPower', 'NRSectorCarrier.ulCalibrationData', 'NRSectorCarrier.longitude', 'NRSectorCarrier.coverage', 'NRSectorCarrier.rfBranchRxRef', 'NRSectorCarrier.nullSteeringMode', 'NRSectorCarrier.frequencyDL', 'NRSectorCarrier.frameStartOffset', 'NRSectorCarrier.essScPairId', 'NRSectorCarrier.radioTransmitPerfMode', 'NRSectorCarrier.txPowerRatio', 'NRSectorCarrier.bSChannelBwUL', 'NRSectorCarrier.configuredMaxTxPower', 'NRSectorCarrier.pimDetectionEnabled', 'NRSectorCarrier.dlCalibrationEnabled', 'NRSectorCarrier.dlCalibrationData', 'NRSectorCarrier.noOfUsedRxAntennas', 'NRSectorCarrier.azimuthNull', 'NRSectorCarrier.frequencyUL', 'NRSectorCarrier.polygon', 'NRSectorCarrier.bSChannelBwDL', 'NRSectorCarrier.cbrsEnabled', 'NRSectorCarrier.reservedBy', 'NRSectorCarrier.noOfRxAntennas', 'NRSectorCarrier.txDirection', 'NRSectorCarrier.operationalState', 'NRSectorCarrier.elevationNull', 'NRSectorCarrier.nRMicroSleepTxEnabled', 'NRSectorCarrier.maxTransmissionPower']
#
#   • Paging: 4 rows, 22 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'Paging.nS', 'Paging.defaultPagingCycle', 'Paging.pagingId', 'Paging.n', 'Paging.nBNbIot', 'Paging.pagingDiscardTimerEdrxNb', 'Paging.pagingDiscardTimerDrxNb', 'Paging.noOfDefPagCyclPrim', 'Paging.maxNoOfPagingRecords', 'Paging.defaultPagingCycleNbIot', 'Paging.pagingDiscardTimerEdrx', 'Paging.maxNoOfPagingRecordsNb', 'Paging.nB', 'Paging.nBBr', 'Paging.pagingDiscardTimerDrx']
#
#   • UeCA: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'UeCA.ueCAId']
#
#   • Rrc: 6 rows, 29 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'Rrc.t319', 'Rrc.t301', 'Rrc.rrcId', 'Rrc.t304', 'Rrc.n310', 'Rrc.n311', 'Rrc.t300', 'Rrc.t311', 'Rrc.t310', 'Rrc.t301Nb', 'Rrc.t311Nb', 'Rrc.t304Br', 'Rrc.t301Br', 'Rrc.t320', 'Rrc.tRetrieveUeInformationNb', 'Rrc.t300NbIot', 'Rrc.tWaitForRrcConnReest', 'Rrc.t300Br', 'Rrc.tRrcConnectionReconfiguration', 'Rrc.tRrcConnReest', 'Rrc.tRrcUeCapabilityInfo', 'Id4']
#
#   • RadioBearerTable: 4 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'RadioBearerTable.radioBearerTableId']
#
#   • AdmissionControl: 4 rows, 82 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'AdmissionControl.rrcMcsPriorityAccessPrio', 'AdmissionControl.rrcReestablishmentPrio', 'AdmissionControl.admissionPrioThreshold', 'AdmissionControl.rrcRnaUpdatePrio', 'AdmissionControl.rrcMoVideoCallPrio', 'AdmissionControl.rrcMtAccessPrio', 'AdmissionControl.rrcMoSignalingPrio', 'AdmissionControl.rrcMoVoiceCallPrio', 'AdmissionControl.rrcEmergencyPrio', 'AdmissionControl.rrcMoSmsPrio', 'AdmissionControl.rrcHighPriorityAccessPrio', 'AdmissionControl.rrcMoDataPrio', 'AdmissionControl.admissionControlId', 'AdmissionControl.rrcMpsPriorityAccessPrio', 'AdmissionControl.admNrRrcDifferentiationThr', 'AdmissionControl.admNrRbDifferentiationThr', 'AdmissionControl.arpBasedPreEmptionState', 'AdmissionControl.limitSrNonPa', 'AdmissionControl.preemptInactTimerMin', 'AdmissionControl.dlMbmsGbrRatio', 'AdmissionControl.resourceReservationForPAState', 'AdmissionControl.nrOfRbReservationsPerPaConn', 'AdmissionControl.nrOfPaConnHpaReservPerCell', 'AdmissionControl.dlAdmDifferentiationThr', 'AdmissionControl.paArpOverrideHpa', 'AdmissionControl.nrOfPrevPreempPaRbReservation', 'AdmissionControl.dlTransNwBandwidth', 'AdmissionControl.lbAtoThresholdLevel2', 'AdmissionControl.lbAtoThresholdLevel1', 'AdmissionControl.zzzTemp4', 'AdmissionControl.admResourceMinQciPrio', 'AdmissionControl.zzzTemp5', 'AdmissionControl.zzzTemp2', 'AdmissionControl.zzzTemp3', 'AdmissionControl.ulNonPaGbrTn', 'AdmissionControl.zzzTemp1', 'AdmissionControl.enhPttAdmCtrlRejPaReqOvlGbr', 'AdmissionControl.dlNonPaGbrTn', 'AdmissionControl.zzzTemporary7', 'AdmissionControl.zzzTemp8', 'AdmissionControl.zzzTemp9', 'AdmissionControl.zzzTemp6', 'AdmissionControl.zzzTemp7', 'AdmissionControl.paArpOverride', 'AdmissionControl.srBbmPaUsersPreallocation', 'AdmissionControl.ulAdmDifferentiationThr', 'AdmissionControl.zzzTemporary28', 'AdmissionControl.resourceReservationForDifferentiation', 'AdmissionControl.zzzTemporary27', 'AdmissionControl.zzzTemporary26', 'AdmissionControl.zzzTemporary25', 'AdmissionControl.nrOfPaConnReservationsPerCell', 'AdmissionControl.zzzTemporary24', 'AdmissionControl.zzzTemporary23', 'AdmissionControl.zzzTemporary22', 'AdmissionControl.zzzTemp19', 'AdmissionControl.zzzTemp17', 'AdmissionControl.zzzTemp18', 'AdmissionControl.zzzTemp15', 'AdmissionControl.zzzTemp16', 'AdmissionControl.zzzTemp13', 'AdmissionControl.zzzTemp14', 'AdmissionControl.ulAdmOverloadThr', 'AdmissionControl.diffAdmCtrlFilteringEnabled', 'AdmissionControl.zzzTemp11', 'AdmissionControl.zzzTemp12', 'AdmissionControl.zzzTemporary1', 'AdmissionControl.dlAdmOverloadThr', 'AdmissionControl.ulTransNwBandwidth', 'AdmissionControl.zzzTemporary2', 'AdmissionControl.zzzTemp10', 'AdmissionControl.zzzTemporary3', 'AdmissionControl.zzzTemporary4', 'AdmissionControl.zzzTemporary5', 'AdmissionControl.zzzTemporary6']
#
#   • S1UTermination: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'S1UTermination.s1UTerminationId']
#
#   • GtpuSupervision: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'GtpuSupervision.gtpuErrorIndDscp', 'GtpuSupervision.gtpuSupervisionId']
#
#   • X2UTermination: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'X2UTermination.x2UTerminationId']
#
#   • PpControlTermination: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PpControlTermination.ppControlTerminationId']
#
#   • RpUserPlaneTermination: 2 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'RpUserPlaneTermination.rpUserPlaneTerminationId']
#
#   • CUUP5qiTable: 2 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'CUUP5qiTable.default5qiTable', 'CUUP5qiTable.reservedBy', 'CUUP5qiTable.cUUP5qiTableId']
#
#   • TermPointToSGW: 108 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'TermPointToSGW.usedIpAddress', 'TermPointToSGW.termPointToSGWId', 'TermPointToSGW.timeOfCreation']
#
#   • PreschedProfile: 10 rows, 13 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PreschedProfile.preschedulingDuration', 'PreschedProfile.reservedBy', 'PreschedProfile.preschedulingSinrThreshold', 'PreschedProfile.preschedulingDataSize', 'PreschedProfile.preschedulingPeriod', 'PreschedProfile.preschedProfileId']
#
#   • SectorCarrier: 15 rows, 50 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'SectorCarrier.noOfTxAntennas', 'SectorCarrier.noOfUsedTxAntennas', 'SectorCarrier.sectorCarrierType', 'SectorCarrier.sectorShape', 'SectorCarrier.essScLocalId', 'SectorCarrier.maxAllowedEirpPsd', 'SectorCarrier.zzzTemporary8', 'SectorCarrier.rfBranchTxRef', 'SectorCarrier.pimMitigLevelThresh', 'SectorCarrier.sectorFunctionRef', 'SectorCarrier.txPowerPersistentLock', 'SectorCarrier.pimMitigDlMutingFixed', 'SectorCarrier.prsEnabled', 'SectorCarrier.availabilityStatus', 'SectorCarrier.rfBranchRxRef', 'SectorCarrier.usedSectorShape', 'SectorCarrier.virtualComChBeamfrmWtsAmplitude', 'SectorCarrier.essScPairId', 'SectorCarrier.radioTransmitPerfMode', 'SectorCarrier.virtualSector', 'SectorCarrier.configuredMaxTxPower', 'SectorCarrier.antCalModeTddAasDl', 'SectorCarrier.maximumTransmissionPower', 'SectorCarrier.noOfUsedRxAntennas', 'SectorCarrier.pimMitigLevel', 'SectorCarrier.zzzTemporary1', 'SectorCarrier.zzzTemporary2', 'SectorCarrier.pimMitigMinIntPwrAutoConfig', 'SectorCarrier.zzzTemporary4', 'SectorCarrier.zzzTemporary5', 'SectorCarrier.zzzTemporary6', 'SectorCarrier.sectorCarrierId', 'SectorCarrier.reservedBy', 'SectorCarrier.pimMitigDlMutingPeriod', 'SectorCarrier.noOfRxAntennas', 'SectorCarrier.ulForcedTimingAdvanceCommand', 'SectorCarrier.beamOverlapEirpControl', 'SectorCarrier.virtualComChBeamfrmWtsPhase', 'SectorCarrier.operationalState', 'SectorCarrier.pimMitigDlMutingPerc', 'SectorCarrier.verticalTaperType', 'SectorCarrier.digitalTilt', 'SectorCarrier.microSleepTxEnabled']
#
#   • PmFlexCounterFilter: 48 rows, 45 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PmFlexCounterFilter.qciFilterMin', 'PmFlexCounterFilter.plmnFilterMin', 'PmFlexCounterFilter.pviFilterMax', 'PmFlexCounterFilter.pmFlexCounterFilterId', 'PmFlexCounterFilter.lcgFilterMax', 'PmFlexCounterFilter.ceLevelFilterEnabled', 'PmFlexCounterFilter.arpFilterEnabled', 'PmFlexCounterFilter.uePowerClassFilterEnabled', 'PmFlexCounterFilter.endcFilterEnabled', 'PmFlexCounterFilter.spidFilterMax', 'PmFlexCounterFilter.subscriberGroupFilterMin', 'PmFlexCounterFilter.ueCatFilterMin', 'PmFlexCounterFilter.lcgFilterMin', 'PmFlexCounterFilter.spidFilterEnabled', 'PmFlexCounterFilter.qciFilterMax', 'PmFlexCounterFilter.uePowerClassFilterMax', 'PmFlexCounterFilter.pciFilterEnabled', 'PmFlexCounterFilter.plmnFilterEnabled', 'PmFlexCounterFilter.spidFilterMin', 'PmFlexCounterFilter.lcgFilterEnabled', 'PmFlexCounterFilter.subscriberGroupFilterMax', 'PmFlexCounterFilter.ceLevelFilterMin', 'PmFlexCounterFilter.arpFilterMax', 'PmFlexCounterFilter.endcFilterMin', 'PmFlexCounterFilter.subscriberGroupFilterEnabled', 'PmFlexCounterFilter.ueCatFilterEnabled', 'PmFlexCounterFilter.ueCatFilterMax', 'PmFlexCounterFilter.pciFilterMax', 'PmFlexCounterFilter.qciFilterEnabled', 'PmFlexCounterFilter.reportAppCounterOnly', 'PmFlexCounterFilter.endcFilterMax', 'PmFlexCounterFilter.uePowerClassFilterMin', 'PmFlexCounterFilter.arpFilterMin', 'PmFlexCounterFilter.pviFilterEnabled', 'PmFlexCounterFilter.ceLevelFilterMax', 'PmFlexCounterFilter.plmnFilterMax', 'PmFlexCounterFilter.pciFilterMin', 'PmFlexCounterFilter.pviFilterMin']
#
#   • RlfProfile: 46 rows, 14 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'RlfProfile.t301', 'RlfProfile.n310', 'RlfProfile.n311', 'RlfProfile.rlfProfileId', 'RlfProfile.reservedBy', 'RlfProfile.t311', 'RlfProfile.t310']
#
#   • IuaProfile: 10 rows, 19 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'IuaProfile.iuaTargetBufferEmptyTime', 'IuaProfile.iuaDuration', 'IuaProfile.iuaProfileId', 'IuaProfile.iuaInactivityTimer', 'IuaProfile.iuaSinrThreshold', 'IuaProfile.iuaUePrbLimit', 'IuaProfile.reservedBy', 'IuaProfile.iuaTargetBufferSize', 'IuaProfile.iuaIntervalTdd', 'IuaProfile.iuaDeactTimer', 'IuaProfile.iuaSinrDeactHyst', 'IuaProfile.iuaIntervalFdd']
#
#   • SubscriberGroupProfile: 18 rows, 54 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'SubscriberGroupProfile.userLabel', 'SubscriberGroupProfile.bearerTriggerList', 'SubscriberGroupProfile.sCellScheduleSinrThresOffset', 'SubscriberGroupProfile.subGroupConfiguration2', 'SubscriberGroupProfile.ulPlThresToRegion', 'SubscriberGroupProfile.subGroupConfiguration1', 'SubscriberGroupProfile.subGroupConfiguration4', 'SubscriberGroupProfile.subGroupConfiguration3', 'SubscriberGroupProfile.subscriberGroupProfileId', 'SubscriberGroupProfile.dlHarqBlerTarget', 'SubscriberGroupProfile.subGroupConfiguration6', 'SubscriberGroupProfile.subGroupConfiguration5', 'SubscriberGroupProfile.preschedulingMode', 'SubscriberGroupProfile.groupExtendInactAfterVolteRel', 'SubscriberGroupProfile.featuresToDisableMeas', 'SubscriberGroupProfile.customTriggerType', 'SubscriberGroupProfile.iuaProfileRef', 'SubscriberGroupProfile.profileIndex', 'SubscriberGroupProfile.spidTriggerList', 'SubscriberGroupProfile.cellTriggerList', 'SubscriberGroupProfile.ulCandidateToRegion', 'SubscriberGroupProfile.ulMcsUpperLimit', 'SubscriberGroupProfile.pZeroNominalPuschOffset', 'SubscriberGroupProfile.qciOffsetForQCI9', 'SubscriberGroupProfile.drxMode', 'SubscriberGroupProfile.qciOffsetForQCI8', 'SubscriberGroupProfile.dlDynBlerTargetMin', 'SubscriberGroupProfile.selectionProbability', 'SubscriberGroupProfile.pZeroNominalPucchOffset', 'SubscriberGroupProfile.qciOffsetForQCI7', 'SubscriberGroupProfile.qciOffsetForQCI6', 'SubscriberGroupProfile.lastSchedLinkAdaptMode', 'SubscriberGroupProfile.preschedProfileRef', 'SubscriberGroupProfile.dlDynBlerTargetAlg', 'SubscriberGroupProfile.iuaMode', 'SubscriberGroupProfile.profilePriority', 'SubscriberGroupProfile.ulHarqBlerTarget', 'SubscriberGroupProfile.customTriggerList', 'SubscriberGroupProfile.caRateAdjustCoeff', 'SubscriberGroupProfile.dlAiLaDeltaSinrMax', 'SubscriberGroupProfile.dlDynBlerTargetMax', 'SubscriberGroupProfile.fastACqiReportEnabled', 'SubscriberGroupProfile.ulSinrThresToRegion', 'SubscriberGroupProfile.pdcchFlexibleBlerMode', 'SubscriberGroupProfile.ulMcsLowerLimit', 'SubscriberGroupProfile.subGroupConfiguration7', 'SubscriberGroupProfile.endcUserProfileRef']
#
#   • QciTable: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'QciTable.qciTableId', 'QciTable.reservedBy']
#
#   • PreschedulingProfile: 2 rows, 13 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PreschedulingProfile.initPreschedulingPeriod', 'PreschedulingProfile.preschedulingDuration', 'PreschedulingProfile.initPreschedulingDuration', 'PreschedulingProfile.preschedulingProfileId', 'PreschedulingProfile.preschedulingDataSize', 'PreschedulingProfile.preschedulingPeriod']
#
#   • PmEventService: 2 rows, 20 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PmEventService.ueTraceFileSize', 'PmEventService.totalCellTraceStorageSize', 'PmEventService.cellTraceHighPrioReserve', 'PmEventService.cellTraceFileSize', 'PmEventService.ueTraceSyncF1AndE1WithX2', 'PmEventService.streamStatusPmCellTrace', 'PmEventService.totalEventStorageSize', 'PmEventService.totalUeTraceStorageSize', 'PmEventService.streamPortPmUeTrace', 'PmEventService.cellTracePeriodicReport', 'PmEventService.streamStatusNotification', 'PmEventService.pmEventServiceId', 'PmEventService.streamStatusPmUeTrace']
#
#   • TermPointToMme: 7 rows, 28 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'TermPointToMme.mmeSupportNbIoT', 'TermPointToMme.usedIpAddress', 'TermPointToMme.ipAddress1', 'TermPointToMme.ipAddress2', 'TermPointToMme.servedPlmnListOtherRATs', 'TermPointToMme.mmeCodeListOtherRATs', 'TermPointToMme.relativeMmeCapacity', 'TermPointToMme.mmeName', 'TermPointToMme.additionalCnRef', 'TermPointToMme.ipv6Address1', 'TermPointToMme.mmeCodeListLTERelated', 'TermPointToMme.ipv6Address2', 'TermPointToMme.mmeSupportLegacyLte', 'TermPointToMme.mmeGIListLTERelated', 'TermPointToMme.servedPlmnListLTERelated', 'TermPointToMme.administrativeState', 'TermPointToMme.domainName', 'TermPointToMme.termPointToMmeId', 'TermPointToMme.availabilityStatus', 'TermPointToMme.operationalState', 'TermPointToMme.dcnType']
#
#   • SubscriberProfileID: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'SubscriberProfileID.userLabel', 'SubscriberProfileID.subscriberProfileIDId']
#
#   • UlCompGroup: 4 rows, 12 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'UlCompGroup.administrativeState', 'UlCompGroup.ulCompGroupId', 'UlCompGroup.availabilityStatus', 'UlCompGroup.operationalState', 'UlCompGroup.sectorCarrierRef']
#
#   • MdtConfiguration: 2 rows, 26 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'MdtConfiguration.rcefReportEnabled', 'MdtConfiguration.immediateMdtGnssCheck', 'MdtConfiguration.maxReportCellsA2Mdt', 'MdtConfiguration.a2ThresholdRsrqMdt', 'MdtConfiguration.rlfReportEnabled', 'MdtConfiguration.a2ThresholdRsrpMdt', 'MdtConfiguration.reportQuantityA2Mdt', 'MdtConfiguration.delayThresholdMdtM6', 'MdtConfiguration.timeToTriggerA2Mdt', 'MdtConfiguration.hysteresisA2Mdt', 'MdtConfiguration.reportingTrigger', 'MdtConfiguration.reportAmountMdtM6', 'MdtConfiguration.triggerQuantityA2Mdt', 'MdtConfiguration.positioningMethod', 'MdtConfiguration.reportIntervalMdt', 'MdtConfiguration.mdtConfigurationId', 'MdtConfiguration.reportIntervalMdtM6', 'MdtConfiguration.reportAmountMdt', 'MdtConfiguration.measGapAllowedMdt']
#
#   • ParameterChangeRequests: 2 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ParameterChangeRequests.parameterChangeRequestsId', 'ParameterChangeRequests.parameterChangeRequestList', 'ParameterChangeRequests.latestUpdate']
#
#   • Rcs: 2 rows, 17 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'Rcs.tInactivityTimerBr', 'Rcs.tNasInactivityTimer', 'Rcs.raiReleaseDelayTimerBr', 'Rcs.rcsId', 'Rcs.tInactivityTimer', 'Rcs.extendInactEmergency', 'Rcs.bufferInactivityTimerBr', 'Rcs.rlcDlDeliveryFailureAction', 'Rcs.extendInactAfterVolteRel', 'Rcs.extendInactEmMode']
#
#   • ImeisvTable: 2 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ImeisvTable.imeisvTableId', 'ImeisvTable.listOfFeaturesDefaultOn', 'ImeisvTable.listOfFeaturesDefaultOff']
#
#   • NonPlannedPciDrxProfile: 2 rows, 11 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NonPlannedPciDrxProfile.nonPlannedPciDrxInactivityTimer', 'NonPlannedPciDrxProfile.nonPlannedPciOnDurationTimer', 'NonPlannedPciDrxProfile.nonPlannedPciDrxProfileId', 'NonPlannedPciDrxProfile.nonPlannedPciLongDrxCycle']
#
#   • NodePerformance: 2 rows, 16 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NodePerformance.zzzTemporary1', 'NodePerformance.zzzTemporary2', 'NodePerformance.zzzTemporary3', 'NodePerformance.zzzTemporary4', 'NodePerformance.zzzTemporary5', 'NodePerformance.zzzTemporary6', 'NodePerformance.nodePerformanceId', 'NodePerformance.zzzTemporary7', 'NodePerformance.zzzTemporary8']
#
#   • PtmFunction: 2 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PtmFunction.ptmEnabled', 'PtmFunction.ptmFunctionId']
#
#   • LoadBalancingFunction: 2 rows, 42 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'LoadBalancingFunction.lbCeiling', 'LoadBalancingFunction.lbHitRateEUtranMeasUeThreshold', 'LoadBalancingFunction.ocdMaxNoHighHitRateCells', 'LoadBalancingFunction.lbHitRateEUtranAddThreshold', 'LoadBalancingFunction.lbHitRateUtranMeasUeThreshold', 'LoadBalancingFunction.lbDiffCaOffset', 'LoadBalancingFunction.lbCauseCodeS1SourceTriggersOffload', 'LoadBalancingFunction.lbSubCycle', 'LoadBalancingFunction.lbUeEvaluationTimer', 'LoadBalancingFunction.lbCycle', 'LoadBalancingFunction.isUlEvalAllowedAtCaTrHo', 'LoadBalancingFunction.lbCauseCodeX2TargetAcceptsOffload', 'LoadBalancingFunction.lbHitRateEUtranMeasUeIntensity', 'LoadBalancingFunction.lbEUtranOffloadBackoffTime', 'LoadBalancingFunction.txPwrForOverlaidCellDetect', 'LoadBalancingFunction.lbCaThreshold', 'LoadBalancingFunction.lbUtranOffloadBackoffTime', 'LoadBalancingFunction.lbCaHysteresis', 'LoadBalancingFunction.targetLoadAwareLbdar', 'LoadBalancingFunction.lbMeasScalingLimit', 'LoadBalancingFunction.loadBalancingFunctionId', 'LoadBalancingFunction.lbHitRateFilterCoeffCalm', 'LoadBalancingFunction.coverageAwareLbdar', 'LoadBalancingFunction.lbCauseCodeX2SourceTriggersOffload', 'LoadBalancingFunction.lbHitRateUtranAddThreshold', 'LoadBalancingFunction.lbHitRateUtranRemoveThreshold', 'LoadBalancingFunction.lbCauseCodeS1TargetAcceptsOffload', 'LoadBalancingFunction.lbHitRateEUtranRemoveThreshold', 'LoadBalancingFunction.lbThreshold', 'LoadBalancingFunction.lbHitRateUtranMeasUeIntensity', 'LoadBalancingFunction.lbCaCapHysteresis', 'LoadBalancingFunction.lbRateOffsetCoefficient', 'LoadBalancingFunction.isUlEvalAllowedAtTpLbHo', 'LoadBalancingFunction.ocdMinHighHitThresh', 'LoadBalancingFunction.lbRateOffsetLoadThreshold']
#
#   • UePolicyOptimization: 2 rows, 15 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'UePolicyOptimization.ueCapPrioList', 'UePolicyOptimization.zzzTemporary1', 'UePolicyOptimization.zzzTemporary2', 'UePolicyOptimization.zzzTemporary3', 'UePolicyOptimization.endcAwareImc', 'UePolicyOptimization.t320', 'UePolicyOptimization.uePolicyOptimizationId', 'UePolicyOptimization.coverageAwareImc']
#
#   • ResourcePartitions: 2 rows, 16 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'ResourcePartitions.zzzTemporary1', 'ResourcePartitions.zzzTemporary2', 'ResourcePartitions.zzzTemporary3', 'ResourcePartitions.zzzTemporary4', 'ResourcePartitions.rrpAdmCtrlRejPaReqOvlGbr', 'ResourcePartitions.zzzTemporary5', 'ResourcePartitions.gbrAdmCtrlPerPartition', 'ResourcePartitions.gbrPartitioning', 'ResourcePartitions.resourcePartitionsId']
#
#   • EndcProfilePredefined: 6 rows, 12 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'EndcProfilePredefined.endcProfilePredefinedId', 'EndcProfilePredefined.meNbS1TermReqArpLev', 'EndcProfilePredefined.reservedBy', 'EndcProfilePredefined.splitNotAllowedUeArpLev', 'EndcProfilePredefined.userLabelPredefined']
#
#   • EUtranCellTDD: 3 rows, 486 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'EUtranCellTDD.ns05LowBandSchedMode', 'EUtranCellTDD.tPollRetxRrcReleaseDl', 'EUtranCellTDD.upperLayerAutoConfEnabled', 'EUtranCellTDD.cceDynUeAdmCtrlOverloadThr', 'EUtranCellTDD.aiAdvCellSupMode', 'EUtranCellTDD.dynUeAdmCtrlEnabled', 'EUtranCellTDD.outOfCoverageThreshold', 'EUtranCellTDD.optimizedPdcchCongestThres', 'EUtranCellTDD.freqBand', 'EUtranCellTDD.plmn1AbConfProfileRef', 'EUtranCellTDD.cellCapMaxCellSubCap', 'EUtranCellTDD.loadBasedCaEnabled', 'EUtranCellTDD.servOrPrioIFHoSetupBearer', 'EUtranCellTDD.rtpTimeout', 'EUtranCellTDD.uncertSemiMajor', 'EUtranCellTDD.iflbAbEnabled', 'EUtranCellTDD.pagingPriorityDiffThr', 'EUtranCellTDD.lbabBarringPriorityLevel', 'EUtranCellTDD.sCellHandlingAtVolteCall', 'EUtranCellTDD.zzzTemporary7', 'EUtranCellTDD.zzzTemporary8', 'EUtranCellTDD.measGapPattern', 'EUtranCellTDD.eDrxAllowed', 'EUtranCellTDD.zzzTemporary9', 'EUtranCellTDD.antennaSelectionEnabled', 'EUtranCellTDD.covTriggerdBlindHoAllowed', 'EUtranCellTDD.prsConfigIndex', 'EUtranCellTDD.acBarringForMoData', 'EUtranCellTDD.rachNoOfAllocationsPerFrame', 'EUtranCellTDD.ulHeavyUeDetectEnabled', 'EUtranCellTDD.additionalPlmnReservedList', 'EUtranCellTDD.tm9ModeSwitchingEnabled', 'EUtranCellTDD.eranUlCompUserSelSinrThr', 'EUtranCellTDD.additionalMultipleNSPmax', 'EUtranCellTDD.zzzTemporary3', 'EUtranCellTDD.zzzTemporary4', 'EUtranCellTDD.zzzTemporary5', 'EUtranCellTDD.zzzTemporary6', 'EUtranCellTDD.reservedBy', 'EUtranCellTDD.tUeBlockingTimer', 'EUtranCellTDD.initialBufferSizeMsg5Default', 'EUtranCellTDD.qciTableRef', 'EUtranCellTDD.prsMutingPattern', 'EUtranCellTDD.sectorCarrierRef', 'EUtranCellTDD.p0ClpcExGoodSinrOffset64Qam', 'EUtranCellTDD.dsrTransMax', 'EUtranCellTDD.qRxLevMinOffset', 'EUtranCellTDD.rateShapingActive', 'EUtranCellTDD.loadBasedCaMsrThr', 'EUtranCellTDD.activePlmnList', 'EUtranCellTDD.cellRange', 'EUtranCellTDD.siPeriodicity', 'EUtranCellTDD.ailgActive', 'EUtranCellTDD.administrativeState', 'EUtranCellTDD.aiSrsAllocEnabled', 'EUtranCellTDD.lbabThreshTimeHigh', 'EUtranCellTDD.advCellSupAction', 'EUtranCellTDD.siValidityTimeBr', 'EUtranCellTDD.siWindowLength', 'EUtranCellTDD.ulSrsEnable', 'EUtranCellTDD.blerTargetConfigEnabled', 'EUtranCellTDD.lbUtranOffloadThreshold', 'EUtranCellTDD.ulVolteCovMobThr', 'EUtranCellTDD.deallocTimerPucchFormat1', 'EUtranCellTDD.minInterfSchedEnabled', 'EUtranCellTDD.ulSCellPriority', 'EUtranCellTDD.cellId', 'EUtranCellTDD.pagingPriorityOverloadThr', 'EUtranCellTDD.primaryPlmnAlarmSuppr', 'EUtranCellTDD.rwrSearchZoneAllowed', 'EUtranCellTDD.moVoiceDynUeAdmCtrlPrio', 'EUtranCellTDD.rachPreambleRepetition', 'EUtranCellTDD.minInterfUlRegionSize', 'EUtranCellTDD.liteMcsReduction', 'EUtranCellTDD.eCallOverImsSupport', 'EUtranCellTDD.qQualMin', 'EUtranCellTDD.gpsTimeSFN0Seconds', 'EUtranCellTDD.expectedMaxNoOfUsersInCell', 'EUtranCellTDD.dlMaxRetxRrcReleaseThr', 'EUtranCellTDD.dlConfigurableFrequencyStart', 'EUtranCellTDD.pucchOverdimensioning', 'EUtranCellTDD.cioLowerLimitAdjBySon', 'EUtranCellTDD.spifhoDedicatedReportConfig', 'EUtranCellTDD.hoOptStatTime', 'EUtranCellTDD.drxActive', 'EUtranCellTDD.cfraEnable', 'EUtranCellTDD.dynUeAdmCtrlFilterConst', 'EUtranCellTDD.lbEUtranCellOffloadCapacity', 'EUtranCellTDD.srDetectHighThres', 'EUtranCellTDD.alpha', 'EUtranCellTDD.dlPowerChangeRate', 'EUtranCellTDD.catmMbmsDlSubframes', 'EUtranCellTDD.validDlBrSubframes', 'EUtranCellTDD.tm9Allowed', 'EUtranCellTDD.tReorderingAutoConfiguration', 'EUtranCellTDD.spifhoSetupBearerAtInitialCtxtSetup', 'EUtranCellTDD.primaryPsdOffset', 'EUtranCellTDD.prsPowerBoosting', 'EUtranCellTDD.ulPsdLoadThresholdSinrClpc', 'EUtranCellTDD.noOfEnhAdptReTxCand', 'EUtranCellTDD.prsMutingPatternLen', 'EUtranCellTDD.enableUeAssistedAdaptiveDrx', 'EUtranCellTDD.dlInterferenceManagementActive', 'EUtranCellTDD.prsTransmisScheme', 'EUtranCellTDD.acBarringForEmergency', 'EUtranCellTDD.lbabMinBarringFactor', 'EUtranCellTDD.prioAdditi ...
#
#   • DrxProfile: 40 rows, 18 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'DrxProfile.shortDrxCycleTimer', 'DrxProfile.longDrxCycleOnly', 'DrxProfile.onDurationTimer', 'DrxProfile.shortDrxCycle', 'DrxProfile.drxProfileId', 'DrxProfile.drxRetransmissionTimer', 'DrxProfile.drxInactivityTimer', 'DrxProfile.drxState', 'DrxProfile.longDrxCycle', 'Id4', 'DrxProfile.reservedBy']
#
#   • CellSleepNodeFunction: 2 rows, 13 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'CellSleepNodeFunction.csmEutranInterFMeasReportIncr', 'CellSleepNodeFunction.csmMinHitRateForCovCell', 'CellSleepNodeFunction.csmEutranInterFMeasReportDecr', 'CellSleepNodeFunction.csmEutranInterFMeasReportMax', 'CellSleepNodeFunction.cellSleepNodeFunctionId', 'CellSleepNodeFunction.csmEutranInterFMeasReportMin']
#
#   • CarrierAggregationFunction: 2 rows, 58 columns
# ...
#
#   • AutonomousMode: 2 rows, 11 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'AutonomousMode.expiration', 'AutonomousMode.activationState', 'AutonomousMode.autonomousModeId']
#
#   • HcRule: 94 rows, 18 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'HcRule.severity', 'HcRule.recommendedAction', 'HcRule.hcRuleId', 'HcRule.administrativeState', 'HcRule.ruleType', 'HcRule.categoryList', 'HcRule.name', 'HcRule.description', 'HcRule.inputParameters', 'HcRule.outputParameters']
#
#   • BrmRollbackAtRestore: 2 rows, 11 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'BrmRollbackAtRestore.timeRemainingBeforeRollback', 'BrmRollbackAtRestore.brmRollbackAtRestoreId', 'BrmRollbackAtRestore.timeAllowedBeforeRollback']
#
#   • BrmBackupManager: 2 rows, 16 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'BrmBackupManager.backupDomain', 'BrmBackupManager.progressReport', 'BrmBackupManager.brmBackupManagerId', 'BrmBackupManager.autoExport', 'BrmBackupManager.autoExportUri', 'BrmBackupManager.manualBackupName', 'BrmBackupManager.autoExportPassword', 'BrmBackupManager.backupType']
#
#   • HwItem: 52 rows, 23 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'HwItem.additionalInformation', 'HwItem.serialNumber', 'HwItem.equipmentMoRef', 'HwItem.dateOfLastService', 'HwItem.hwType', 'HwItem.hwUnitLocation', 'HwItem.productData', 'HwItem.manualDataEntry', 'HwItem.vendorName', 'HwItem.hwCapability', 'HwItem.hwModel', 'HwItem.hwName', 'HwItem.licMgmtMoRef', 'HwItem.swInvMoRef', 'HwItem.hwItemId']
#
#   • AntennaUnitGroup: 9 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'AntennaUnitGroup.positionRef', 'AntennaUnitGroup.positionInformation', 'AntennaUnitGroup.antennaUnitGroupId']
#
#   • Cabinet: 1 rows, 17 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'Cabinet.userLabel', 'Cabinet.positionRef', 'Cabinet.cabinetId', 'Cabinet.smokeDetector', 'Cabinet.climateSystem', 'Cabinet.productData', 'Cabinet.climateRegulationSystem', 'Cabinet.sharedCabinetIdentifier', 'Cabinet.cabinetIdentifier', 'Cabinet.alarmInExternalMe']
#
#   • EcBus: 1 rows, 11 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'EcBus.ecBusConnectorRef', 'EcBus.ecBusId', 'EcBus.equipmentSupportFunctionRef', 'EcBus.ecBusConnectionType']
#
#   • PowerDistribution: 1 rows, 12 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PowerDistribution.userLabel', 'PowerDistribution.systemUndervoltageAlarmLevel', 'PowerDistribution.systemOvervoltageAlarmLevel', 'PowerDistribution.availabilityStatus', 'PowerDistribution.powerDistributionId']
#
#   • PowerSupply: 1 rows, 14 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'PowerSupply.nominalVoltage', 'PowerSupply.smartLoadSharingConfig', 'PowerSupply.userLabel', 'PowerSupply.smartLoadSharing', 'PowerSupply.availabilityStatus', 'PowerSupply.powerSupplyId', 'PowerSupply.multiplePowerSystem']
#
#   • Climate: 1 rows, 14 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'Climate.climateId', 'Climate.userLabel', 'Climate.climateControlMode', 'Climate.boostInternalThreshold', 'Climate.availabilityStatus', 'Climate.fanSpeedSupervision', 'Climate.enhancedModeSetup']
#
#   • NbIotCell: 3 rows, 146 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'NbIotCell.attachWithoutPDNConnectivityList', 'NbIotCell.npbchRrmConfigEnabled', 'NbIotCell.mappingInfo', 'NbIotCell.plmnAlarmSupprList', 'NbIotCell.physicalLayerCellId', 'NbIotCell.rachPreambleTransMaxNb', 'NbIotCell.additionalSpectrumEmissionValues', 'NbIotCell.cellBarred', 'NbIotCell.periodicBsrTimerDedicated', 'NbIotCell.enableMfbi', 'NbIotCell.qHyst', 'NbIotCell.sInterSearchThreshold', 'NbIotCell.nbIotCellType', 'NbIotCell.nbIotCellCoverage', 'NbIotCell.preambleIniRecTargetPowerCe1', 'NbIotCell.freqBand', 'NbIotCell.maxRrcConnectedUsers', 'NbIotCell.rlcStatusPduDelayDl', 'NbIotCell.tTatDedicatedNbCe2', 'NbIotCell.preambleIniRecTargetPowerR14', 'NbIotCell.nbIotCellPolygon', 'NbIotCell.abContConfFromLastProfile', 'NbIotCell.rsrpThreshold2', 'NbIotCell.ulNonAnchPrbIndex', 'NbIotCell.maxNumPreambleAttemptNbCe1', 'NbIotCell.rsrpThreshold1', 'NbIotCell.maxNumPreambleAttemptNbCe2', 'NbIotCell.ulAnchPrbIndex', 'NbIotCell.minNumLargeRmaxUes', 'NbIotCell.pZeroNominalNPusch', 'NbIotCell.maxNumPreambleAttemptNbCe0', 'NbIotCell.nbIotDynOverloadUlNonAnchThr', 'NbIotCell.dlAnchPrbUtilThr', 'NbIotCell.operationalState', 'NbIotCell.tRrcConnReest', 'NbIotCell.abConfProfileRef', 'NbIotCell.latitude', 'NbIotCell.dlNonAnchPrbUtilThr', 'NbIotCell.ulNonAnchPrbUtilThr', 'NbIotCell.primaryFreqBand', 'NbIotCell.abMinIntensityThreshold', 'NbIotCell.plmnIdList', 'NbIotCell.nprachCapMode4RxEnabled', 'NbIotCell.nprachSubcarrierForStMsg3Ce2', 'NbIotCell.cmcIndex', 'NbIotCell.nprachSubcarrierForStMsg3Ce1', 'NbIotCell.nprachSubcarrierForStMsg3Ce0', 'NbIotCell.spectrumEmissionReqMapping', 'NbIotCell.earfcndl', 'NbIotCell.dlNonAnchPrbIndex', 'NbIotCell.intraFrequencyInfo', 'NbIotCell.nsssRrmConfigInterFreq', 'NbIotCell.anchPowerBoostGainIndex', 'NbIotCell.sIntraSearchThreshold', 'NbIotCell.nbIotDynOverloadDlAnchThr', 'NbIotCell.inactivitySupervisionTimer', 'NbIotCell.earfcnul', 'NbIotCell.dlLaIpnAbsolute', 'NbIotCell.enhancedRaPowerCtrl', 'NbIotCell.sectorCarrierRef', 'NbIotCell.raBackoffNbCe2', 'NbIotCell.raBackoffNbCe1', 'NbIotCell.raiEnabled', 'NbIotCell.raBackoffNbCe0', 'NbIotCell.plmnReservedList', 'NbIotCell.abThreshTimeHigh', 'NbIotCell.nbIotAcPresence', 'NbIotCell.nbIotCellId', 'NbIotCell.activePlmnList', 'NbIotCell.cellRange', 'NbIotCell.administrativeState', 'NbIotCell.frequencyInfo', 'NbIotCell.tac', 'NbIotCell.raDlSinrAdjustCe', 'NbIotCell.msg3CqiAdjustFactorCe', 'NbIotCell.siWindowLength', 'NbIotCell.longitude', 'NbIotCell.abThreshRejectLow', 'NbIotCell.dlNonAnchPrbNum', 'NbIotCell.nbDlSinrAdjust', 'NbIotCell.enhancedPhr', 'NbIotCell.cellId', 'NbIotCell.nbIotDynOverloadDlNonAnchThr', 'NbIotCell.sIntraSearchDeltaP', 'NbIotCell.networkSignallingValue', 'NbIotCell.additionalFreqBandList', 'NbIotCell.npuschGroupHopConfig', 'NbIotCell.ulAnchPrbUtilThr', 'NbIotCell.useHostCellPci', 'NbIotCell.cDrxEnabled', 'NbIotCell.largeRmaxUeAnchThr', 'NbIotCell.ulNonAnchPrbNum', 'NbIotCell.qQualMin', 'NbIotCell.zzzTemporary18', 'NbIotCell.userLabel', 'NbIotCell.zzzTemporary17', 'NbIotCell.zzzTemporary14', 'NbIotCell.zzzTemporary13', 'NbIotCell.zzzTemporary12', 'NbIotCell.zzzTemporary11', 'NbIotCell.hostingDigitalUnitRef', 'NbIotCell.ceLevelNumber', 'NbIotCell.raNpuschSinrAdjustCe', 'NbIotCell.preambleIniRecTargetPower', 'NbIotCell.eutranCellRef', 'NbIotCell.alpha', 'NbIotCell.nbIotDynOverloadUlAnchThr', 'NbIotCell.tTatDedicatedNbCe1', 'NbIotCell.availabilityStatus', 'NbIotCell.qRxLevMin', 'NbIotCell.tTatDedicatedNbCe0', 'NbIotCell.nonPolledReleaseCfg', 'NbIotCell.raiReleaseDelayTimer', 'NbIotCell.msg3CqiReportEnabled', 'NbIotCell.raNprachSinrAdjustCe', 'NbIotCell.pMax', 'NbIotCell.preschedUlGrantDelay', 'NbIotCell.nsssRrmConfigEnabled', 'NbIotCell.zzzTemporary26', 'NbIotCell.zzzTemporary25', 'NbIotCell.zzzTemporary24', 'NbIotCell.microSleepTxPattern', 'NbIotCell.zzzTemporary23', 'NbIotCell.zzzTemporary22', 'NbIotCell.zzzTemporary21', 'NbIotCell.dataInactivityTim ...
#
#   • SpectrumSharingFunction: 1 rows, 8 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'SpectrumSharingFunction.spectrumSharingFunctionId']
#
#   • EUtranCellFDD: 9 rows, 497 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'EUtranCellFDD.ns05LowBandSchedMode', 'EUtranCellFDD.tPollRetxRrcReleaseDl', 'EUtranCellFDD.upperLayerAutoConfEnabled', 'EUtranCellFDD.cceDynUeAdmCtrlOverloadThr', 'EUtranCellFDD.aiAdvCellSupMode', 'EUtranCellFDD.dynUeAdmCtrlEnabled', 'EUtranCellFDD.outOfCoverageThreshold', 'EUtranCellFDD.optimizedPdcchCongestThres', 'EUtranCellFDD.freqBand', 'EUtranCellFDD.plmn1AbConfProfileRef', 'EUtranCellFDD.ttiBundlingAfterHo', 'EUtranCellFDD.cellCapMaxCellSubCap', 'EUtranCellFDD.loadBasedCaEnabled', 'EUtranCellFDD.servOrPrioIFHoSetupBearer', 'EUtranCellFDD.rtpTimeout', 'EUtranCellFDD.iflbAbEnabled', 'EUtranCellFDD.uncertSemiMajor', 'EUtranCellFDD.pagingPriorityDiffThr', 'EUtranCellFDD.lbabBarringPriorityLevel', 'EUtranCellFDD.eabThreshRejRateLteHighBr', 'EUtranCellFDD.eabThreshTimeHigh', 'EUtranCellFDD.eabPresenceBr', 'EUtranCellFDD.sCellHandlingAtVolteCall', 'EUtranCellFDD.measGapPattern', 'EUtranCellFDD.eDrxAllowed', 'EUtranCellFDD.covTriggerdBlindHoAllowed', 'EUtranCellFDD.prsConfigIndex', 'EUtranCellFDD.acBarringForMoData', 'EUtranCellFDD.ulHeavyUeDetectEnabled', 'EUtranCellFDD.rachNoOfAllocationsPerFrame', 'EUtranCellFDD.ulCatmEssShare', 'EUtranCellFDD.additionalPlmnReservedList', 'EUtranCellFDD.eranUlCompUserSelSinrThr', 'EUtranCellFDD.ttiBundlingAtSetup', 'EUtranCellFDD.ulChannelBandwidth', 'EUtranCellFDD.additionalMultipleNSPmax', 'EUtranCellFDD.highestSupportedCeLevelBr', 'EUtranCellFDD.maxRrcConnectedUsersBr', 'EUtranCellFDD.tUeBlockingTimer', 'EUtranCellFDD.initialBufferSizeMsg5Default', 'EUtranCellFDD.reservedBy', 'EUtranCellFDD.qciTableRef', 'EUtranCellFDD.prsMutingPattern', 'EUtranCellFDD.sectorCarrierRef', 'EUtranCellFDD.dsrTransMax', 'EUtranCellFDD.p0ClpcExGoodSinrOffset64Qam', 'EUtranCellFDD.qRxLevMinOffset', 'EUtranCellFDD.rateShapingActive', 'EUtranCellFDD.loadBasedCaMsrThr', 'EUtranCellFDD.channelSelectionSetSize', 'EUtranCellFDD.activePlmnList', 'EUtranCellFDD.siPeriodicity', 'EUtranCellFDD.cellRange', 'EUtranCellFDD.ailgActive', 'EUtranCellFDD.ulInternalChannelBandwidth', 'EUtranCellFDD.administrativeState', 'EUtranCellFDD.lbabThreshTimeHigh', 'EUtranCellFDD.advCellSupAction', 'EUtranCellFDD.siValidityTimeBr', 'EUtranCellFDD.siWindowLength', 'EUtranCellFDD.ulSrsEnable', 'EUtranCellFDD.blerTargetConfigEnabled', 'EUtranCellFDD.lbUtranOffloadThreshold', 'EUtranCellFDD.ulVolteCovMobThr', 'EUtranCellFDD.deallocTimerPucchFormat1', 'EUtranCellFDD.ulSCellPriority', 'EUtranCellFDD.minInterfSchedEnabled', 'EUtranCellFDD.cellId', 'EUtranCellFDD.noOfPuschNbBr', 'EUtranCellFDD.pagingPriorityOverloadThr', 'EUtranCellFDD.beamWeightSet16Tr', 'EUtranCellFDD.primaryPlmnAlarmSuppr', 'EUtranCellFDD.rwrSearchZoneAllowed', 'EUtranCellFDD.liteMcsReduction', 'EUtranCellFDD.minInterfUlRegionSize', 'EUtranCellFDD.rachPreambleRepetition', 'EUtranCellFDD.moVoiceDynUeAdmCtrlPrio', 'EUtranCellFDD.eCallOverImsSupport', 'EUtranCellFDD.qQualMin', 'EUtranCellFDD.gpsTimeSFN0Seconds', 'EUtranCellFDD.expectedMaxNoOfUsersInCell', 'EUtranCellFDD.distributedEssInvalidSfDlBr', 'EUtranCellFDD.dlMaxRetxRrcReleaseThr', 'EUtranCellFDD.dlCatmEssShareSrb0', 'EUtranCellFDD.dlConfigurableFrequencyStart', 'EUtranCellFDD.pucchOverdimensioning', 'EUtranCellFDD.cioLowerLimitAdjBySon', 'EUtranCellFDD.eabThreshRejRateLteLowBr', 'EUtranCellFDD.spifhoDedicatedReportConfig', 'EUtranCellFDD.hoOptStatTime', 'EUtranCellFDD.drxActive', 'EUtranCellFDD.cfraEnable', 'EUtranCellFDD.dynUeAdmCtrlFilterConst', 'EUtranCellFDD.lbEUtranCellOffloadCapacity', 'EUtranCellFDD.alpha', 'EUtranCellFDD.srDetectHighThres', 'EUtranCellFDD.eabConfProfileBrRef', 'EUtranCellFDD.catmMbmsDlSubframes', 'EUtranCellFDD.dlPowerChangeRate', 'EUtranCellFDD.validDlBrSubframes', 'EUtranCellFDD.tReorderingAutoConfiguration', 'EUtranCellFDD.spifhoSetupBearerAtInitialCtxtSetup', 'EUtranCellFDD.primaryPsdOffset', 'EUtranCellFDD.prsPowerBoosting', 'EUtranCellFDD.ulPsdLoadThresholdSinrClpc', 'EUtranCellFDD.pimDetec ...
#
#   • GsmSector: 6 rows, 11 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'vsDataType', 'vsDataFormatVersion', 'GsmSector.gsmSectorId', 'GsmSector.userLabel', 'GsmSector.bscTgIdentity', 'GsmSector.bscNodeIdentity']
#
#   • AntennaUnit: 9 rows, 17 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'AntennaUnit.mechanicalAntennaTilt', 'AntennaUnit.mechanicalAntennaBearing', 'AntennaUnit.numberOfLogicalArrays', 'AntennaUnit.positionWithinSector', 'AntennaUnit.sectorLabel', 'AntennaUnit.antennaUnitId', 'AntennaUnit.antennaModelNumber', 'AntennaUnit.antennaSerialNumber', 'AntennaUnit.antennaDataProvenance']
#
#   • RfBranch: 36 rows, 23 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'RfBranch.ulAttenuationPerFqRange', 'RfBranch.userLabel', 'RfBranch.ulTrafficDelayPerFqRange', 'RfBranch.dlTrafficDelay', 'RfBranch.dlAttenuationPerFqRange', 'RfBranch.auPortRef', 'RfBranch.dlAttenuation', 'RfBranch.ulAttenuation', 'RfBranch.rfPortRef', 'RfBranch.tmaRef', 'RfBranch.dlTrafficDelayPerFqRange', 'RfBranch.reservedBy', 'RfBranch.bandList', 'RfBranch.ulTrafficDelay', 'RfBranch.rfBranchId']
#
#   • FanGroup: 4 rows, 9 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'FanGroup.fanGroupId']
#
#   • AlarmPort: 4 rows, 20 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'AlarmPort.userLabel', 'AlarmPort.administrativeState', 'AlarmPort.perceivedSeverity', 'AlarmPort.alarmSlogan', 'AlarmPort.alarmPortId', 'AlarmPort.filterDelay', 'AlarmPort.availabilityStatus', 'AlarmPort.operationalState', 'AlarmPort.filterTime', 'AlarmPort.filterAlgorithm', 'AlarmPort.normallyOpen', 'AlarmPort.alarmInExternalMe']
#
#   • EUtranCellRelation: 3 rows, 16 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'EUtranCellRelation.userLabel', 'EUtranCellRelation.isHoAllowed', 'EUtranCellRelation.eUtranCellRelationId', 'EUtranCellRelation.isRemoveAllowed', 'EUtranCellRelation.essCellScPairs', 'EUtranCellRelation.cellIndividualOffset', 'EUtranCellRelation.neighborCellRef', 'EUtranCellRelation.essEnabled']
#
#   • PmUlInterferenceReport: 39 rows, 10 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'PmUlInterferenceReport.rfBranchRxRef', 'PmUlInterferenceReport.pmUlInterferenceReportId']
#
#   • SharingGroup: 3 rows, 13 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'SharingGroup.schedPolicy', 'SharingGroup.gUtranCellRelationRef', 'SharingGroup.userLabel', 'SharingGroup.sharingGroupId', 'SharingGroup.eUtranCellRef']
#
#   • Trx: 12 rows, 26 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'Trx.rfBranchRxRef', 'Trx.userLabel', 'Trx.combinedCellType', 'Trx.reservedMaxTxPower', 'Trx.sectorEquipmentFunctionRef', 'Trx.noOfTxAntennas', 'Trx.rxImbMinNoOfSamples', 'Trx.arfcnMax', 'Trx.frequencyBand', 'Trx.configuredMaxTxPower', 'Trx.trxId', 'Trx.rxImbAlarmThreshold', 'Trx.rfBranchRx', 'Trx.trxIndex', 'Trx.administrativeState', 'Trx.rxImbSupWindowSize', 'Trx.noOfRxAntennas', 'Trx.arfcnMin']
#
#   • AbisIp: 6 rows, 19 columns
#     Columns: ['dateTime', 'Area_Name', 'SiteName', 'Id2', 'Id3', 'Id4', 'vsDataType', 'vsDataFormatVersion', 'AbisIp.userLabel', 'AbisIp.gsmSectorName', 'AbisIp.initialRetransmissionPeriod', 'AbisIp.administrativeState', 'AbisIp.retransmissionCap', 'AbisIp.abisIpId', 'AbisIp.ipv4Address', 'AbisIp.dscpSectorControlUL', 'AbisIp.bscBrokerIpAddress', 'AbisIp.maxRetransmission', 'AbisIp.keepAlivePeriod']

# %%
# Step 2: Initialize Neo4j Connection
print("🔗 Connecting to Neo4j...")

# Neo4j connection parameters
NEO4J_URI = "bolt://localhost:7687"
NEO4J_USER = "neo4j"
NEO4J_PASSWORD = "ranqarag#1"  # Change this to your actual password

try:
    # Initialize the integrator
    integrator = RANNeo4jIntegrator(
        neo4j_uri=NEO4J_URI,
        neo4j_user=NEO4J_USER,
        neo4j_password=NEO4J_PASSWORD
    )
    print("✅ Successfully connected to Neo4j!")
    print(f"📊 Embedding model: {integrator.embedding_model}")
    print(f"🎯 Similarity threshold: {integrator.similarity_threshold}")
    
except Exception as e:
    print(f"❌ Failed to connect to Neo4j: {e}")
    print("Please ensure Neo4j is running and credentials are correct.")
# Out:
# 🔗 Connecting to Neo4j...
# ✅ Successfully connected to Neo4j!
# 📊 Embedding model: SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False, 'architecture': 'BertModel'})
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )
# 🎯 Similarity threshold: 0.7

# %%
# Step 3.1: Create Table Nodes
print("🔹 Creating table nodes...")
integrator.create_table_nodes(dfs)
# Out:
# 🔹 Creating table nodes...
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/neo4j/_async_compat/network/_bolt_socket.py:409, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, keep_alive, ssl_context)
#     408 log.debug("[#0000]  C: <OPEN> %s", resolved_address)
# --> 409 s.connect(resolved_address)
#     410 s.settimeout(t)
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt_socket.py:328, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     327 try:
# --> 328     s = cls._connect_secure(
#     329         resolved_address, tcp_timeout, keep_alive, ssl_context
#     330     )
#     331     agreed_version, handshake, response = s._handshake(
#     332         resolved_address, deadline
#     333     )
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_async_compat/network/_bolt_socket.py:426, in BoltSocketBase._connect_secure(cls, resolved_address, timeout, keep_alive, ssl_context)
#     425 if isinstance(error, OSError):
# --> 426     raise ServiceUnavailable(
#     427         "Failed to establish connection to "
#     428         f"{resolved_address!r} (reason {error})"
#     429     ) from error
#     430 raise
#
# ServiceUnavailable: Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
#
# The above exception was the direct cause of the following exception:
#
# ServiceUnavailable                        Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Step 3.1: Create Table Nodes
#       2 print("🔹 Creating table nodes...")
# ----> 3 integrator.create_table_nodes(dfs)
#
# File /workspaces/ran_intelligent_management/knowledge_graph_module/kg_builder.py:351, in RANNeo4jIntegrator.create_table_nodes(self, dataframes_dict)
#     349     for table_name, df in dataframes_dict.items():
#     350         metadata = self.extract_table_metadata(df, table_name)
# --> 351         session.run("""
#     352             MERGE (t:Table {name: $name})
#     353             SET t.row_count = $row_count,
#     354                 t.column_count = $column_count,
#     355                 t.created_at = $created_at
#     356         """, **metadata)
#     357 print("✅ Table nodes created successfully.")
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/session.py:315, in Session.run(self, query, parameters, **kwargs)
#     312     self._auto_result._buffer_all()
#     314 if not self._connection:
# --> 315     self._connect(self._config.default_access_mode)
#     316     assert self._connection is not None
#     317 cx = self._connection
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/session.py:136, in Session._connect(self, access_mode, **acquire_kwargs)
#     134     access_mode = self._config.default_access_mode
#     135 try:
# --> 136     super()._connect(
#     137         access_mode, auth=self._config.auth, **acquire_kwargs
#     138     )
#     139 except asyncio.CancelledError:
#     140     self._handle_cancellation(message="_connect")
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/work/workspace.py:199, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     189 acquire_kwargs_ = {
#     190     "access_mode": access_mode,
#     191     "timeout": acquisition_timeout,
#    (...)
#     196     "database_callback": self._make_db_resolution_callback(),
#     197 }
#     198 acquire_kwargs_.update(acquire_kwargs)
# --> 199 self._connection = self._pool.acquire(**acquire_kwargs_)
#     200 if (
#     201     target_db.guessed
#     202     and not self._pinned_database
#    (...)
#     206     # support SSR.
#     207     # => we need to fall back to explicit home database resolution
#     208     log.debug(
#     209         "[#0000]  _: <WORKSPACE> detected ssr support race; "
#     210         "falling back to explicit home database resolution",
#     211     )
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:676, in BoltPool.acquire(self, access_mode, timeout, database, bookmarks, auth, liveness_check_timeout, unprepared, database_callback)
#     669 log.debug(
#     670     "[#0000]  _: <POOL> acquire direct connection, "
#     671     "access_mode=%r, database=%r",
#     672     access_mode,
#     673     database,
#     674 )
#     675 deadline = Deadline.from_timeout_or_deadline(timeout)
# --> 676 return self._acquire(
#     677     self.address, auth, deadline, liveness_check_timeout, unprepared
#     678 )
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:417, in IOPool._acquire(self, address, auth, deadline, liveness_check_timeout, unprepared)
#     412             raise ClientError(
#     413                 "failed to obtain a connection from the pool within "
#     414                 f"{deadline.original_timeout!r}s (timeout)"
#     415             )
#     416 log.debug("[#0000]  _: <POOL> trying to hand out new connection")
# --> 417 return connection_creator()
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:230, in IOPool._acquire_new_later.<locals>.connection_creator()
#     228 try:
#     229     try:
# --> 230         connection = self.opener(
#     231             address, auth or self.pool_config.auth, deadline
#     232         )
#     233     except ServiceUnavailable:
#     234         self.deactivate(address)
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:637, in BoltPool.open.<locals>.opener(addr, auth_manager, deadline)
#     636 def opener(addr, auth_manager, deadline):
# --> 637     return Bolt.open(
#     638         addr,
#     639         auth_manager=auth_manager,
#     640         deadline=deadline,
#     641         routing_context=None,
#     642         pool_config=pool_config,
#     643     )
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:368, in Bolt.open(cls, address, auth_manager, deadline, routing_context, pool_config)
#     365 if deadline is None:
#     366     deadline = Deadline(None)
# --> 368 s, protocol_version, handshake, data = BoltSocket.connect(
#     369     address,
#     370     tcp_timeout=pool_config.connection_timeout,
#     371     deadline=deadline,
#     372     custom_resolver=pool_config.resolver,
#     373     ssl_context=pool_config.get_ssl_context(),
#     374     keep_alive=pool_config.keep_alive,
#     375 )
#     377 pool_config.protocol_version = protocol_version
#     378 protocol_handlers = Bolt.protocol_handlers
#
# File ~/.local/lib/python3.10/site-packages/neo4j/_sync/io/_bolt_socket.py:376, in BoltSocket.connect(cls, address, tcp_timeout, deadline, custom_resolver, ssl_context, keep_alive)
#     374 else:
#     375     error_strs = "\n".join(map(str, errors))
# --> 376     raise ServiceUnavailable(
#     377         f"Couldn't connect to {address} (resolved to {address_strs}):"
#     378         f"\n{error_strs}"
#     379     ) from errors[0]
#
# ServiceUnavailable: Couldn't connect to localhost:7687 (resolved to ('[::1]:7687', '127.0.0.1:7687')):
# Failed to establish connection to ResolvedIPv6Address(('::1', 7687, 0, 0)) (reason [Errno 111] Connection refused)
# Failed to establish connection to ResolvedIPv4Address(('127.0.0.1', 7687)) (reason [Errno 111] Connection refused)

# %%
# Step 3: Create Knowledge Graph
print("🏗️ Creating knowledge graph in Neo4j...")

try:
    # Create nodes and relationships in Neo4j
    integrator.create_nodes_and_relationships(dfs)
    print("✅ Successfully created nodes and relationships in Neo4j!")
    
    # Verify the graph creation
    with integrator.driver.session() as session:
        # Count nodes and relationships
        table_count = session.run("MATCH (t:Table) RETURN count(t) as count").single()['count']
        column_count = session.run("MATCH (c:Column) RETURN count(c) as count").single()['count']
        
        relationship_stats = session.run("""
            MATCH ()-[r]-()
            RETURN type(r) as rel_type, count(r) as count
            ORDER BY count DESC
        """).data()
        
        print(f"\n📊 Knowledge Graph Statistics:")
        print(f"  • Tables: {table_count}")
        print(f"  • Columns: {column_count}")
        print(f"  • Relationships:")
        
        total_relationships = 0
        for stat in relationship_stats:
            print(f"    - {stat['rel_type']}: {stat['count']}")
            total_relationships += stat['count']
        
        print(f"\n🎉 KNOWLEDGE GRAPH CREATION COMPLETE!")
        print(f"━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
        print(f"📊 Created {table_count} table nodes and {column_count} column nodes")
        print(f"🔗 Established {total_relationships} semantic relationships")
        print(f"⚡ Graph is ready for querying and chatbot integration!")
        print(f"━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
            
except Exception as e:
    print(f"❌ Error creating knowledge graph: {e}")
    print("Please check your Neo4j connection and try again.")

# Clean up
try:
    integrator.close()
    print("\n✅ Neo4j connection closed successfully.")
except:
    pass

# %%
# Step 3: Create Knowledge Graph
print("🏗️ Creating knowledge graph in Neo4j...")

try:
    # Step 3.1: Create Table Nodes
    print("🔹 Creating table nodes...")
    integrator.create_table_nodes(dfs)

    # Step 3.2: Create Column Nodes and Relationships
    print("🔹 Creating column nodes and relationships...")
    integrator.create_column_nodes_and_relationships(dfs)

    # Step 3.3: Create Semantic Relationships
    print("🔹 Creating semantic relationships...")
    integrator.create_semantic_relationships(dfs)

    print("✅ Knowledge graph creation completed successfully!")

    # Verify the graph creation
    with integrator.driver.session() as session:
        # Count nodes and relationships
        table_count = session.run("MATCH (t:Table) RETURN count(t) as count").single()['count']
        column_count = session.run("MATCH (c:Column) RETURN count(c) as count").single()['count']

        relationship_stats = session.run("""
            MATCH ()-[r]-()
            RETURN type(r) as rel_type, count(r) as count
            ORDER BY count DESC
        """).data()

        print(f"\n📊 Knowledge Graph Statistics:")
        print(f"  • Tables: {table_count}")
        print(f"  • Columns: {column_count}")
        print(f"  • Relationships:")

        total_relationships = 0
        for stat in relationship_stats:
            print(f"    - {stat['rel_type']}: {stat['count']}")
            total_relationships += stat['count']

        print(f"\n🎉 KNOWLEDGE GRAPH CREATION COMPLETE!")
        print(f"━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
        print(f"📊 Created {table_count} table nodes and {column_count} column nodes")
        print(f"🔗 Established {total_relationships} semantic relationships")
        print(f"⚡ Graph is ready for querying and chatbot integration!")
        print(f"━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━")
            
except Exception as e:
    print(f"❌ Error creating knowledge graph: {e}")
    print("Please check your Neo4j connection and try again.")

# Clean up
try:
    integrator.close()
    print("\n✅ Neo4j connection closed successfully.")
except:
    pass
