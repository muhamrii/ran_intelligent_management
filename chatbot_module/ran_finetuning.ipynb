# %% [markdown]
# # RAN Domain-Specific Model Fine-tuning
#
# This notebook guides you through the process of fine-tuning a language model specifically for RAN (Radio Access Network) knowledge graph queries.
#
# ## Overview
# - **Knowledge Graph**: 273 tables, 5,584 columns, 4M+ relationships
# - **Goal**: Create a domain-specific model that understands RAN terminology
# - **Process**: Data generation → Model training → Evaluation → Deployment
#
# ## Prerequisites
# - Neo4j database with RAN knowledge graph
# - Required Python packages (see requirements.txt)
# - GPU recommended for faster training

# %% [markdown]
# ## 1. Setup and Dependencies

# %%
# Install required packages if not already installed
# !pip install transformers datasets torch accelerate
# !pip install neo4j sentence-transformers scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers in /home/vscode/.local/lib/python3.10/site-packages (4.54.1)
# Requirement already satisfied: datasets in /home/vscode/.local/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: torch in /home/vscode/.local/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: accelerate in /home/vscode/.local/lib/python3.10/site-packages (1.10.0)
# Requirement already satisfied: transformers in /home/vscode/.local/lib/python3.10/site-packages (4.54.1)
# Requirement already satisfied: datasets in /home/vscode/.local/lib/python3.10/site-packages (4.0.0)
# Requirement already satisfied: torch in /home/vscode/.local/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: accelerate in /home/vscode/.local/lib/python3.10/site-packages (1.10.0)
# Requirement already satisfied: filelock in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (2025.7.34)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Requirement already satisfied: filelock in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (0.34.3)
# Requirement already satisfied: numpy>=1.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (2025.7.34)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: tqdm>=4.27 in /home/vscode/.local/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (1.1.5)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (2.3.1)
# Requirement already satisfied: xxhash in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (2.3.1)
# Requirement already satisfied: xxhash in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/vscode/.local/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/vscode/.local/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: sympy>=1.13.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /home/vscode/.local/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/vscode/.local/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.15)
# Requirement already satisfied: sympy>=1.13.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /home/vscode/.local/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.10/site-packages (from triton==3.3.1->torch) (75.6.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.10/site-packages (from triton==3.3.1->torch) (75.6.0)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.10/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10)
# Requirement already satisfied: psutil in /home/vscode/.local/lib/python3.10/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/vscode/.local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: idna>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers) (2025.8.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/vscode/.local/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/vscode/.local/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/vscode/.local/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/vscode/.local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: neo4j in /home/vscode/.local/lib/python3.10/site-packages (5.28.2)
# Requirement already satisfied: sentence-transformers in /home/vscode/.local/lib/python3.10/site-packages (5.0.0)
# Requirement already satisfied: scikit-learn in /home/vscode/.local/lib/python3.10/site-packages (1.7.1)
# Requirement already satisfied: pytz in /home/vscode/.local/lib/python3.10/site-packages (from neo4j) (2025.2)
# Requirement already satisfied: neo4j in /home/vscode/.local/lib/python3.10/site-packages (5.28.2)
# Requirement already satisfied: sentence-transformers in /home/vscode/.local/lib/python3.10/site-packages (5.0.0)
# Requirement already satisfied: scikit-learn in /home/vscode/.local/lib/python3.10/site-packages (1.7.1)
# Requirement already satisfied: pytz in /home/vscode/.local/lib/python3.10/site-packages (from neo4j) (2025.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (4.54.1)
# Requirement already satisfied: tqdm in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scipy in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (0.34.3)
# Requirement already satisfied: Pillow in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (4.54.1)
# Requirement already satisfied: tqdm in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: scipy in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (0.34.3)
# Requirement already satisfied: Pillow in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from sentence-transformers) (4.14.1)
# Requirement already satisfied: filelock in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.7.34)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: filelock in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.7.34)
# Requirement already satisfied: requests in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.4)
# Requirement already satisfied: safetensors>=0.4.3 in /home/vscode/.local/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Requirement already satisfied: joblib>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/vscode/.local/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.5)
# Requirement already satisfied: joblib>=1.2.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: sympy>=1.13.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.10/site-packages (from triton==3.3.1->torch>=1.11.0->sentence-transformers) (75.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /home/vscode/.local/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.10/site-packages (from triton==3.3.1->torch>=1.11.0->sentence-transformers) (75.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/vscode/.local/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/vscode/.local/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/vscode/.local/lib/python3.10/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.8.3)

# %%
# Import required libraries
import sys
import os
import json
import torch
import numpy as np
import pandas as pd
from datetime import datetime
import logging
import warnings
warnings.filterwarnings('ignore')

# Set up logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

print(f"Python version: {sys.version}")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA device: {torch.cuda.get_device_name()}")
# Out:
# Python version: 3.10.18 (main, Jul  1 2025, 05:26:40) [GCC 12.2.0]
# PyTorch version: 2.7.1+cu126
# CUDA available: False

# %%
# Import our custom modules
sys.path.append('..')
from ran_finetuning import RANDomainModelTrainer, RANEntityRecognitionTrainer
from knowledge_graph_module.kg_builder import RANNeo4jIntegrator

print("✅ Modules imported successfully")
# Out:
# Transformers version: 4.54.1
# ✅ Modules imported successfully
# ✅ Modules imported successfully

# %% [markdown]
# ## 2. Database Connection Setup

# %%
# Configure your Neo4j connection
NEO4J_URI = "bolt://localhost:7687"  # Update with your Neo4j URI
NEO4J_USERNAME = "neo4j"              # Update with your username
NEO4J_PASSWORD = "ranqarag#1"           # Update with your password

# Initialize Neo4j connection
try:
    neo4j_integrator = RANNeo4jIntegrator(NEO4J_URI, NEO4J_USERNAME, NEO4J_PASSWORD)
    print("✅ Neo4j connection established")
    
    # Test connection with a simple query
    with neo4j_integrator.driver.session() as session:
        result = session.run("MATCH (n) RETURN count(n) as total_nodes")
        total_nodes = result.single()['total_nodes']
        print(f"📊 Total nodes in knowledge graph: {total_nodes:,}")
        
except Exception as e:
    print(f"❌ Failed to connect to Neo4j: {e}")
    print("Please check your connection settings and ensure Neo4j is running")
    neo4j_integrator = None
# Out:
# INFO:sentence_transformers.SentenceTransformer:Use pytorch device_name: cpu
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# INFO:sentence_transformers.SentenceTransformer:Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# ✅ Neo4j connection established
# 📊 Total nodes in knowledge graph: 5,857

# %% [markdown]
# ## 3. Explore Knowledge Graph Structure

# %%
# Get overview of the knowledge graph
if neo4j_integrator:
    with neo4j_integrator.driver.session() as session:
        # Count different node types
        tables_count = session.run("MATCH (t:Table) RETURN count(t) as count").single()['count']
        columns_count = session.run("MATCH (c:Column) RETURN count(c) as count").single()['count']
        
        # Count different relationship types
        rel_types = session.run("""
            MATCH ()-[r]->()
            RETURN type(r) as rel_type, count(r) as count
            ORDER BY count DESC
        """)
        
        print("📊 Knowledge Graph Overview:")
        print(f"   Tables: {tables_count:,}")
        print(f"   Columns: {columns_count:,}")
        print("\n🔗 Relationship Types:")
        
        rel_data = []
        for record in rel_types:
            rel_type = record['rel_type']
            count = record['count']
            print(f"   {rel_type}: {count:,}")
            rel_data.append({'Relationship Type': rel_type, 'Count': count})
        
        # Create a DataFrame for better visualization
        rel_df = pd.DataFrame(rel_data)
        print("\n📈 Relationship Distribution:")
        print(rel_df.to_string(index=False))
# Out:
# 📊 Knowledge Graph Overview:
#    Tables: 273
#    Columns: 5,584
#
# 🔗 Relationship Types:
#    CONCEPTUAL_GROUP: 3,870,783
#    PATTERN_MATCH: 850,776
#    NAME_SIMILARITY: 452,809
#    VALUE_OVERLAP: 130,360
#    REFERENCES: 101,712
#    HAS_COLUMN: 5,584
#
# 📈 Relationship Distribution:
# Relationship Type   Count
#  CONCEPTUAL_GROUP 3870783
#     PATTERN_MATCH  850776
#   NAME_SIMILARITY  452809
#     VALUE_OVERLAP  130360
#        REFERENCES  101712
#        HAS_COLUMN    5584
#    CONCEPTUAL_GROUP: 3,870,783
#    PATTERN_MATCH: 850,776
#    NAME_SIMILARITY: 452,809
#    VALUE_OVERLAP: 130,360
#    REFERENCES: 101,712
#    HAS_COLUMN: 5,584
#
# 📈 Relationship Distribution:
# Relationship Type   Count
#  CONCEPTUAL_GROUP 3870783
#     PATTERN_MATCH  850776
#   NAME_SIMILARITY  452809
#     VALUE_OVERLAP  130360
#        REFERENCES  101712
#        HAS_COLUMN    5584

# %%
# Sample some table and column names to understand the data
if neo4j_integrator:
    with neo4j_integrator.driver.session() as session:
        # Sample table names
        sample_tables = session.run("""
            MATCH (t:Table)
            RETURN t.name as table_name, t.row_count as rows, t.column_count as cols
            ORDER BY t.row_count DESC
            LIMIT 100
        """)
        
        print("🏆 Top 100 Tables by Row Count:")
        table_data = []
        for record in sample_tables:
            table_name = record['table_name']
            rows = record['rows'] or 0
            cols = record['cols'] or 0
            print(f"   {table_name}: {rows:,} rows, {cols} columns")
            table_data.append({
                'Table Name': table_name,
                'Rows': rows,
                'Columns': cols
            })
        
        tables_df = pd.DataFrame(table_data)
        print("\n📊 Tables Summary:")
        print(tables_df.to_string(index=False))
# Out:
# 🏆 Top 100 Tables by Row Count:
#    FeatureState: 945 rows, 15 columns
#    FeatureKey: 708 rows, 16 columns
#    SctpAssociation: 409 rows, 10 columns
#    ExternalENodeBFunction: 390 rows, 35 columns
#    Schema: 374 rows, 14 columns
#    NRCellRelation: 182 rows, 20 columns
#    SwItem: 151 rows, 13 columns
#    TermPointToSGW: 108 rows, 10 columns
#    HcRule: 94 rows, 18 columns
#    ExternalGNodeBFunction: 83 rows, 16 columns
#    ExternalGeranCell: 79 rows, 36 columns
#    EUtranFreqRelation: 72 rows, 89 columns
#    ExternalGNBCUCPFunction: 65 rows, 14 columns
#    CapacityState: 63 rows, 17 columns
#    X2ULink: 56 rows, 11 columns
#    HwItem: 52 rows, 23 columns
#    S1ULink: 52 rows, 11 columns
#    PmFlexCounterFilter: 48 rows, 45 columns
#    RlfProfile: 46 rows, 14 columns
#    EUtranFrequency: 43 rows, 26 columns
#    Log: 40 rows, 11 columns
#    DrxProfile: 40 rows, 18 columns
#    PmUlInterferenceReport: 39 rows, 10 columns
#    GeranFrequency: 38 rows, 14 columns
#    SciProfile: 38 rows, 26 columns
#    RfBranch: 36 rows, 23 columns
#    CapacityKey: 32 rows, 19 columns
#    SfpModule: 32 rows, 10 columns
#    RfPort: 30 rows, 27 columns
#    QciProfilePredefined: 28 rows, 64 columns
#    RiPort: 27 rows, 14 columns
#    GeranFreqGroupRelation: 24 rows, 33 columns
#    GUtranFreqRelation: 24 rows, 27 columns
#    RpUserPlaneLink: 23 rows, 11 columns
#    CUUP5qi: 18 rows, 22 columns
#    SubscriberGroupProfile: 18 rows, 54 columns
#    QciProfileOperatorDefined: 16 rows, 64 columns
#    SectorCarrier: 15 rows, 50 columns
#    InterfaceIPv4: 15 rows, 25 columns
#    FmAlarm: 14 rows, 9 columns
#    VlanPort: 14 rows, 18 columns
#    Router: 13 rows, 15 columns
#    MimoSleepFunction: 12 rows, 25 columns
#    Etws: 12 rows, 9 columns
#    CellPerformance: 12 rows, 17 columns
#    InstantUplinkAccess: 12 rows, 24 columns
#    UeMeasControl: 12 rows, 97 columns
#    CellSleepFunction: 12 rows, 38 columns
#    RATFreqPrio: 12 rows, 18 columns
#    Trx: 12 rows, 26 columns
#    NRFreqRelation: 12 rows, 35 columns
#    RouteTableIPv4Static: 11 rows, 9 columns
#    FieldReplaceableUnit: 11 rows, 19 columns
#    EnergyMeter: 11 rows, 12 columns
#    IuaProfile: 10 rows, 19 columns
#    PreschedProfile: 10 rows, 13 columns
#    SctpEndpoint: 10 rows, 18 columns
#    EUtranCellFDD: 9 rows, 497 columns
#    RiLink: 9 rows, 15 columns
#    SectorEquipmentFunction: 9 rows, 20 columns
#    AntennaUnitGroup: 9 rows, 10 columns
#    AntennaUnit: 9 rows, 17 columns
#    EventProducerS: 8 rows, 10 columns
#    EventProducer: 8 rows, 10 columns
#    LogicalChannelGroup: 8 rows, 11 columns
#    LocalSctpEndpoint: 8 rows, 11 columns
#    TnPort: 7 rows, 13 columns
#    TermPointToMme: 7 rows, 28 columns
#    Rrc: 6 rows, 29 columns
#    NRCellCU: 6 rows, 50 columns
#    NRSectorCarrier: 6 rows, 54 columns
#    EndcProfile: 6 rows, 12 columns
#    NRCellDU: 6 rows, 158 columns
#    SctpProfile: 6 rows, 43 columns
#    EndcProfilePredefined: 6 rows, 12 columns
#    CommonBeamforming: 6 rows, 19 columns
#    DlOuterLoop: 6 rows, 15 columns
#    HereIAmIndication: 6 rows, 10 columns
#    EndpointResource: 6 rows, 10 columns
#    AntennaNearUnit: 6 rows, 27 columns
#    GsmSector: 6 rows, 11 columns
#    NRFrequency: 6 rows, 18 columns
#    AbisIp: 6 rows, 19 columns
#    EthernetPort: 5 rows, 24 columns
#    SecurityHandling: 4 rows, 15 columns
#    UpgradePackage: 4 rows, 18 columns
#    TwampInitiator: 4 rows, 10 columns
#    UeCC: 4 rows, 8 columns
#    NtpServer: 4 rows, 9 columns
#    OamAccessPoint: 4 rows, 10 columns
#    AdmissionControl: 4 rows, 82 columns
#    RadioBearerTable: 4 rows, 8 columns
#    AnrFunction: 4 rows, 48 columns
#    GUtranSyncSignalFrequency: 4 rows, 19 columns
#    Paging: 4 rows, 22 columns
#    FastCoordinationGroup: 4 rows, 11 columns
#    PtmCellProfile: 4 rows, 11 columns
#    GeranFreqGroup: 4 rows, 12 columns
#    DataRadioBearer: 4 rows, 17 columns
#    SignalingRadioBearer: 4 rows, 21 columns
#
# 📊 Tables Summary:
#                Table Name  Rows  Columns
#              FeatureState   945       15
#                FeatureKey   708       16
#           SctpAssociation   409       10
#    ExternalENodeBFunction   390       35
#                    Schema   374       14
#            NRCellRelation   182       20
#                    SwItem   151       13
#            TermPointToSGW   108       10
#                    HcRule    94       18
#    ExternalGNodeBFunction    83       16
#         ExternalGeranCell    79       36
#        EUtranFreqRelation    72       89
#   ExternalGNBCUCPFunction    65       14
#             CapacityState    63       17
#                   X2ULink    56       11
#                    HwItem    52       23
#                   S1ULink    52       11
#       PmFlexCounterFilter    48       45
#                RlfProfile    46       14
#           EUtranFrequency    43       26
#                       Log    40       11
#                DrxProfile    40       18
#    PmUlInterferenceReport    39       10
#            GeranFrequency    38       14
#                SciProfile    38       26
#                  RfBranch    36       23
#               CapacityKey    32       19
#                 SfpModule    32       10
#                    RfPort    30       27
#      QciProfilePredefined    28       64
#                    RiPort    27       14
#    GeranFreqGroupRelation    24       33
#        GUtranFreqRelation    24       27
#           RpUserPlaneLink    23       11
#                   CUUP5qi    18       22
#    SubscriberGroupProfile    18       54
# QciProfileOperatorDefined    16       64
#             SectorCarrier    15       50
#             InterfaceIPv4    15       25
#                   FmAlarm    14        9
#                  VlanPort    14       18
#                    Router    13       15
#         MimoSleepFunction    12       25
#                      Etws    12        9
#           CellPerformance    12       17
#       InstantUplinkAccess    12       24
#             UeMeasControl    12       97
#         CellSleepFunction    12       38
#               RATFreqPrio    12       18
#                       Trx    12       26
#            NRFreqRelation    12       35
#      RouteTableIPv4Static    11        9
#      FieldReplaceableUnit    11       19
#               EnergyMeter    11       12
#                IuaProfile    10       19
#           PreschedProfile    10       13
#              SctpEndpoint    10       18
#             EUtranCellFDD     9      497
#                    RiLink     9       15
#   SectorEquipmentFunction     9       20
#          AntennaUnitGroup     9       10
#               AntennaUnit     9       17
#            EventProducerS     8       10
#             EventProducer     8       10
#       LogicalChannelGroup     8       11
#         LocalSctpEndpoint     8       11
#                    TnPort     7       13
#            TermPointToMme     7       28
#                       Rrc     6       29
#                  NRCellCU     6       50
#           NRSectorCarrier     6       54
#               EndcProfile     6       12
#                  NRCellDU     6      158
#               SctpProfile     6       43
#     EndcProfilePredefined     6       12
#         CommonBeamforming     6       19
#               DlOuterLoop     6       15
#         HereIAmIndication     6       10
#          EndpointResource     6       10
#           AntennaNearUnit     6       27
#                 GsmSector     6       11
#               NRFrequency     6       18
#                    AbisIp     6       19
#              EthernetPort     5       24
#          SecurityHandling     4       15
#            UpgradePackage     4       18
#            TwampInitiator     4       10
#                      UeCC     4        8
#                 NtpServer     4        9
#            OamAccessPoint     4       10
#          AdmissionControl     4       82
#          RadioBearerTable     4        8
#               AnrFunction     4       48
# GUtranSyncSignalFrequency     4       19
#                    Paging     4       22
#     FastCoordinationGroup     4       11
#            PtmCellProfile     4       11
#            GeranFreqGroup     4       12
#           DataRadioBearer     4       17
#      SignalingRadioBearer     4       21

# %%
# Sample some conceptual groups to understand semantic categories
if neo4j_integrator:
    with neo4j_integrator.driver.session() as session:
        conceptual_groups = session.run("""
            MATCH (c1:Column)-[r:CONCEPTUAL_GROUP]-(c2:Column)
            WHERE r.semantic_category IS NOT NULL
            WITH r.semantic_category as category, count(r) as relationship_count
            RETURN category, relationship_count
            ORDER BY relationship_count DESC
            LIMIT 100
        """)
        
        print("🎯 Top Semantic Categories:")
        category_data = []
        for record in conceptual_groups:
            category = record['category']
            count = record['relationship_count']
            print(f"   {category}: {count:,} relationships")
            category_data.append({
                'Semantic Category': category,
                'Relationships': count
            })
        
        if category_data:
            categories_df = pd.DataFrame(category_data)
            print("\n📈 Semantic Categories Distribution:")
            print(categories_df.to_string(index=False))
        else:
            print("   No semantic categories found with the current query")
# Out:
# 🎯 Top Semantic Categories:
#    network_topology: 2,791,422 relationships
#    quality: 1,612,858 relationships
#    frequency: 884,566 relationships
#    general: 472,906 relationships
#    configuration_parameters: 437,738 relationships
#    topology: 434,332 relationships
#    traffic_analysis: 349,212 relationships
#    frequency_spectrum: 208,452 relationships
#    timing_synchronization: 198,936 relationships
#    traffic: 147,424 relationships
#    quality_metrics: 104,442 relationships
#    configuration: 75,344 relationships
#    performance_metrics: 13,904 relationships
#    power_management: 9,824 relationships
#    mobility_management: 130 relationships
#    security_features: 76 relationships
#
# 📈 Semantic Categories Distribution:
#        Semantic Category  Relationships
#         network_topology        2791422
#                  quality        1612858
#                frequency         884566
#                  general         472906
# configuration_parameters         437738
#                 topology         434332
#         traffic_analysis         349212
#       frequency_spectrum         208452
#   timing_synchronization         198936
#                  traffic         147424
#          quality_metrics         104442
#            configuration          75344
#      performance_metrics          13904
#         power_management           9824
#      mobility_management            130
#        security_features             76
#    network_topology: 2,791,422 relationships
#    quality: 1,612,858 relationships
#    frequency: 884,566 relationships
#    general: 472,906 relationships
#    configuration_parameters: 437,738 relationships
#    topology: 434,332 relationships
#    traffic_analysis: 349,212 relationships
#    frequency_spectrum: 208,452 relationships
#    timing_synchronization: 198,936 relationships
#    traffic: 147,424 relationships
#    quality_metrics: 104,442 relationships
#    configuration: 75,344 relationships
#    performance_metrics: 13,904 relationships
#    power_management: 9,824 relationships
#    mobility_management: 130 relationships
#    security_features: 76 relationships
#
# 📈 Semantic Categories Distribution:
#        Semantic Category  Relationships
#         network_topology        2791422
#                  quality        1612858
#                frequency         884566
#                  general         472906
# configuration_parameters         437738
#                 topology         434332
#         traffic_analysis         349212
#       frequency_spectrum         208452
#   timing_synchronization         198936
#                  traffic         147424
#          quality_metrics         104442
#            configuration          75344
#      performance_metrics          13904
#         power_management           9824
#      mobility_management            130
#        security_features             76

# %% [markdown]
# ## 4. Initialize Fine-tuning Components

# %%
# Initialize the RAN domain model trainer
if neo4j_integrator:
    ran_trainer = RANDomainModelTrainer(neo4j_integrator)
    print("✅ RAN Domain Model Trainer initialized")
    
    # Display the RAN intents that will be trained
    print("\n🎯 RAN Domain Intents:")
    for i, (intent, description) in enumerate(ran_trainer.ran_intents.items(), 1):
        print(f"   {i:2d}. {intent}: {description}")
    
    print(f"\n📝 Total intents: {len(ran_trainer.ran_intents)}")
else:
    print("❌ Cannot initialize trainer without Neo4j connection")
    ran_trainer = None
# Out:
# ✅ RAN Domain Model Trainer initialized
#
# 🎯 RAN Domain Intents:
#     1. performance_analysis: Analyze network performance metrics and KPIs
#     2. power_optimization: Optimize power consumption and efficiency
#     3. spectrum_management: Manage frequency spectrum allocation and bandwidth
#     4. cell_configuration: Configure cell parameters and settings
#     5. quality_assessment: Assess signal quality and coverage metrics
#     6. traffic_analysis: Analyze network traffic patterns and load
#     7. fault_detection: Detect and diagnose network faults and issues
#     8. capacity_planning: Plan network capacity and resource allocation
#     9. interference_analysis: Analyze and mitigate interference sources
#    10. handover_optimization: Optimize handover procedures and mobility
#
# 📝 Total intents: 10

# %%
# Initialize the NER trainer
if neo4j_integrator:
    ner_trainer = RANEntityRecognitionTrainer(neo4j_integrator)
    print("✅ RAN Entity Recognition Trainer initialized")
    
    print("\n🏷️ Entity Types for NER:")
    for entity_type, label in ner_trainer.entity_types.items():
        print(f"   {entity_type}: {label}")
else:
    print("❌ Cannot initialize NER trainer without Neo4j connection")
    ner_trainer = None
# Out:
# ✅ RAN Entity Recognition Trainer initialized
#
# 🏷️ Entity Types for NER:
#    TABLE_NAME: B-TAB
#    COLUMN_NAME: B-COL
#    CELL_ID: B-CELL
#    FREQUENCY: B-FREQ
#    POWER_VALUE: B-PWR
#    METRIC_NAME: B-MET
#    TIME_VALUE: B-TIME

# %%
# Final Test: Generate Training Data with More Semantic Categories
print("🎯 Final Test: Enhanced Training Data Generation")
print("=" * 50)

if ran_trainer:
    # Reload to get the latest limit increase
    import importlib
    from ran_finetuning import RANDomainModelTrainer
    ran_trainer = RANDomainModelTrainer(neo4j_integrator)
    
    print("🔄 Generating training data with expanded coverage...")
    enhanced_training_data = ran_trainer.generate_training_data()
    
    print(f"✅ Generated {len(enhanced_training_data)} enhanced training samples")
    
    # Analyze entity coverage
    samples_with_entities = sum(1 for item in enhanced_training_data if item.get('entities'))
    categories_found = set()
    entity_fields_found = set()
    
    for item in enhanced_training_data:
        entities = item.get('entities', {})
        if entities.get('semantic_category'):
            categories_found.add(entities['semantic_category'])
        for field in entities.keys():
            entity_fields_found.add(field)
    
    print(f"\n📊 Enhanced Analysis:")
    print(f"   Total samples: {len(enhanced_training_data)}")
    print(f"   Samples with entities: {samples_with_entities} ({(samples_with_entities/len(enhanced_training_data)*100):.1f}%)")
    print(f"   Unique semantic categories: {len(categories_found)}")
    print(f"   Unique entity field types: {len(entity_fields_found)}")
    
    print(f"\n🏷️ Semantic Categories Found:")
    for i, category in enumerate(sorted(categories_found), 1):
        print(f"   {i:2d}. {category}")
    
    print(f"\n🔧 Entity Field Types Available:")
    for i, field in enumerate(sorted(entity_fields_found), 1):
        print(f"   {i:2d}. {field}")
    
    # Show a few diverse samples
    print(f"\n🎯 Sample Enhanced Training Data:")
    categories_shown = set()
    for item in enhanced_training_data:
        if len(categories_shown) >= 3:  # Show 3 different categories
            break
        
        category = item.get('entities', {}).get('semantic_category', 'unknown')
        if category not in categories_shown and category != 'unknown':
            categories_shown.add(category)
            print(f"\n📝 Category: {category}")
            print(f"   Text: '{item['text'][:80]}...'")
            print(f"   Intent: {item['intent']}")
            
            entities = item.get('entities', {})
            key_entities = ['table_name', 'column_name', 'semantic_category', 'domain_type', 'entity_confidence']
            print(f"   Key Entities:")
            for key in key_entities:
                if key in entities:
                    print(f"      • {key}: {entities[key]}")
    
    print(f"\n✅ Training data is now properly enhanced with rich entity information!")
    print(f"🚀 Ready for model training with real KG data representation!")

else:
    print("❌ No trainer available")
# Out:
# 🎯 Final Test: Enhanced Training Data Generation
# ==================================================
# 🔄 Generating training data with expanded coverage...
# 🔍 Extracting real KG data for training...
# 📊 Extracted 10888 real entities from 16 categories
# ✅ Generated 1180 training samples with entities
# ✅ Generated 1180 enhanced training samples
#
# 📊 Enhanced Analysis:
#    Total samples: 1180
#    Samples with entities: 1180 (100.0%)
#    Unique semantic categories: 16
#    Unique entity field types: 19
#
# 🏷️ Semantic Categories Found:
#     1. configuration
#     2. configuration_parameters
#     3. frequency
#     4. frequency_spectrum
#     5. general
#     6. mobility_management
#     7. network_topology
#     8. performance_metrics
#     9. power_management
#    10. quality
#    11. quality_metrics
#    12. security_features
#    13. timing_synchronization
#    14. topology
#    15. traffic
#    16. traffic_analysis
#
# 🔧 Entity Field Types Available:
#     1. analysis_type
#     2. column_name
#     3. column_type
#     4. comparison_type
#     5. config_type
#     6. domain_type
#     7. entity_confidence
#     8. extraction_source
#     9. measurement_type
#    10. mobility_type
#    11. network_element
#    12. query_type
#    13. search_type
#    14. security_type
#    15. semantic_category
#    16. structure_type
#    17. sync_type
#    18. table_name
#    19. table_type
#
# 🎯 Sample Enhanced Training Data:
#
# 📝 Category: network_topology
#    Text: 'Show network topology data from SubscriberGroupProfile.cellTriggerList in Subscr...'
#    Intent: cell_configuration
#    Key Entities:
#       • table_name: SubscriberGroupProfile
#       • column_name: SubscriberGroupProfile.cellTriggerList
#       • semantic_category: network_topology
#       • domain_type: network_topology
#       • entity_confidence: high
#
# 📝 Category: quality
#    Text: 'Show signal quality from userLabel...'
#    Intent: quality_assessment
#    Key Entities:
#       • table_name: EnodeBInfo
#       • column_name: userLabel
#       • semantic_category: quality
#       • domain_type: quality_assessment
#       • entity_confidence: medium
#
# 📝 Category: frequency
#    Text: 'Get frequency data from InstantaneousLicensing.euft in InstantaneousLicensing...'
#    Intent: spectrum_management
#    Key Entities:
#       • table_name: InstantaneousLicensing
#       • column_name: InstantaneousLicensing.euft
#       • semantic_category: frequency
#       • domain_type: frequency_spectrum
#       • entity_confidence: medium
#
# ✅ Training data is now properly enhanced with rich entity information!
# 🚀 Ready for model training with real KG data representation!
# 📊 Extracted 10888 real entities from 16 categories
# ✅ Generated 1180 training samples with entities
# ✅ Generated 1180 enhanced training samples
#
# 📊 Enhanced Analysis:
#    Total samples: 1180
#    Samples with entities: 1180 (100.0%)
#    Unique semantic categories: 16
#    Unique entity field types: 19
#
# 🏷️ Semantic Categories Found:
#     1. configuration
#     2. configuration_parameters
#     3. frequency
#     4. frequency_spectrum
#     5. general
#     6. mobility_management
#     7. network_topology
#     8. performance_metrics
#     9. power_management
#    10. quality
#    11. quality_metrics
#    12. security_features
#    13. timing_synchronization
#    14. topology
#    15. traffic
#    16. traffic_analysis
#
# 🔧 Entity Field Types Available:
#     1. analysis_type
#     2. column_name
#     3. column_type
#     4. comparison_type
#     5. config_type
#     6. domain_type
#     7. entity_confidence
#     8. extraction_source
#     9. measurement_type
#    10. mobility_type
#    11. network_element
#    12. query_type
#    13. search_type
#    14. security_type
#    15. semantic_category
#    16. structure_type
#    17. sync_type
#    18. table_name
#    19. table_type
#
# 🎯 Sample Enhanced Training Data:
#
# 📝 Category: network_topology
#    Text: 'Show network topology data from SubscriberGroupProfile.cellTriggerList in Subscr...'
#    Intent: cell_configuration
#    Key Entities:
#       • table_name: SubscriberGroupProfile
#       • column_name: SubscriberGroupProfile.cellTriggerList
#       • semantic_category: network_topology
#       • domain_type: network_topology
#       • entity_confidence: high
#
# 📝 Category: quality
#    Text: 'Show signal quality from userLabel...'
#    Intent: quality_assessment
#    Key Entities:
#       • table_name: EnodeBInfo
#       • column_name: userLabel
#       • semantic_category: quality
#       • domain_type: quality_assessment
#       • entity_confidence: medium
#
# 📝 Category: frequency
#    Text: 'Get frequency data from InstantaneousLicensing.euft in InstantaneousLicensing...'
#    Intent: spectrum_management
#    Key Entities:
#       • table_name: InstantaneousLicensing
#       • column_name: InstantaneousLicensing.euft
#       • semantic_category: frequency
#       • domain_type: frequency_spectrum
#       • entity_confidence: medium
#
# ✅ Training data is now properly enhanced with rich entity information!
# 🚀 Ready for model training with real KG data representation!

# %%
# Export training data for manual review or external use
if ran_trainer and enhanced_training_data:
    export_path = "./ran_training_data.json"
    
    try:
        ran_trainer.export_training_data(export_path)
        print(f"✅ Training data exported to {export_path}")
        
        # Show file size
        file_size = os.path.getsize(export_path) / (1024 * 1024)  # MB
        print(f"📁 File size: {file_size:.2f} MB")
        
    except Exception as e:
        print(f"❌ Error exporting training data: {e}")
# Out:
# 🔍 Extracting real KG data for training...
# 📊 Extracted 10888 real entities from 16 categories
# ✅ Generated 1180 training samples with entities
# Training data exported to ./ran_training_data.json
# Total samples: 1180
#
# Intent distribution:
#   cell_configuration: 490 samples
#   fault_detection: 60 samples
#   handover_optimization: 30 samples
#   performance_analysis: 180 samples
#   power_optimization: 60 samples
#   quality_assessment: 120 samples
#   spectrum_management: 120 samples
#   traffic_analysis: 120 samples
# ✅ Training data exported to ./ran_training_data.json
# 📁 File size: 0.83 MB
# 📊 Extracted 10888 real entities from 16 categories
# ✅ Generated 1180 training samples with entities
# Training data exported to ./ran_training_data.json
# Total samples: 1180
#
# Intent distribution:
#   cell_configuration: 490 samples
#   fault_detection: 60 samples
#   handover_optimization: 30 samples
#   performance_analysis: 180 samples
#   power_optimization: 60 samples
#   quality_assessment: 120 samples
#   spectrum_management: 120 samples
#   traffic_analysis: 120 samples
# ✅ Training data exported to ./ran_training_data.json
# 📁 File size: 0.83 MB

# %% [markdown]
# ## 7. Model Training Configuration

# %%
# Configure training parameters - Memory Optimized
TRAINING_CONFIG = {
    'model_name': 'distilbert-base-uncased',  # Base model for fine-tuning
    'output_dir': './ran_domain_model',       # Where to save the trained model
    'num_epochs': 2,                          # Reduced epochs to prevent crashes
    'batch_size': 4,                          # Small batch size for memory safety
    'learning_rate': 2e-5,                    # Learning rate
    'warmup_steps': 100,                      # Reduced warmup steps
    'weight_decay': 0.01,                     # Weight decay for regularization
    'logging_steps': 50,                      # More frequent logging
    'save_steps': 500,                        # More frequent saves
    'gradient_accumulation_steps': 2,         # Accumulate gradients to simulate larger batch
}

print("⚙️ Memory-Optimized Training Configuration:")
for key, value in TRAINING_CONFIG.items():
    print(f"   {key}: {value}")

# Auto-adjust based on system capabilities
import psutil
import gc

# Check system memory
system_memory_gb = psutil.virtual_memory().total / (1024**3)
print(f"\n🖥️ System Memory: {system_memory_gb:.1f} GB")

# Check GPU memory if available
if torch.cuda.is_available():
    gpu_memory_gb = torch.cuda.get_device_properties(0).total_memory / (1024**3)
    print(f"🎮 GPU Memory: {gpu_memory_gb:.1f} GB")
    
    # Adjust based on GPU memory
    if gpu_memory_gb < 4:
        TRAINING_CONFIG['batch_size'] = 2
        TRAINING_CONFIG['gradient_accumulation_steps'] = 4
        print("   ⚠️ Low GPU memory - using batch_size=2, gradient_accumulation=4")
    elif gpu_memory_gb < 8:
        TRAINING_CONFIG['batch_size'] = 4
        TRAINING_CONFIG['gradient_accumulation_steps'] = 2
        print("   ✅ Medium GPU memory - using batch_size=4, gradient_accumulation=2")
    else:
        TRAINING_CONFIG['batch_size'] = 8
        TRAINING_CONFIG['gradient_accumulation_steps'] = 1
        print("   🚀 High GPU memory - using batch_size=8, gradient_accumulation=1")
else:
    # CPU-only configuration
    TRAINING_CONFIG['batch_size'] = 2
    TRAINING_CONFIG['gradient_accumulation_steps'] = 4
    TRAINING_CONFIG['num_epochs'] = 2  # Single epoch for CPU
    print("   💻 CPU-only mode - minimal settings for stability")

# Memory cleanup before training
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("\n🧹 Memory cleared and ready for training")
# Out:
# ⚙️ Memory-Optimized Training Configuration:
#    model_name: distilbert-base-uncased
#    output_dir: ./ran_domain_model
#    num_epochs: 2
#    batch_size: 4
#    learning_rate: 2e-05
#    warmup_steps: 100
#    weight_decay: 0.01
#    logging_steps: 50
#    save_steps: 500
#    gradient_accumulation_steps: 2
#
# 🖥️ System Memory: 7.8 GB
#    💻 CPU-only mode - minimal settings for stability

# %% [markdown]
# ## 8. Train the RAN Domain Model

# %%
# Train the intent classification model with memory optimization
if ran_trainer and enhanced_training_data:
    print("🚀 Starting Memory-Optimized RAN Domain Model Training")
    print(f"⏱️ Started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"📊 Training on {len(enhanced_training_data)} samples")
    print("\n⚠️ Note: This uses memory-optimized settings to prevent kernel crashes")
    print("Training may take 15-45 minutes depending on your hardware.")
    print("=" * 60)
    
    # Pre-training memory cleanup
    import gc
    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
        print("🧹 GPU memory cleared before training")
    
    try:
        # Train the model with optimized settings
        print(f"🎯 Training Configuration:")
        print(f"   Model: {TRAINING_CONFIG['model_name']}")
        print(f"   Epochs: {TRAINING_CONFIG['num_epochs']}")
        print(f"   Batch Size: {TRAINING_CONFIG['batch_size']}")
        print(f"   Gradient Accumulation: {TRAINING_CONFIG['gradient_accumulation_steps']}")
        print(f"   Output: {TRAINING_CONFIG['output_dir']}")
        print("")
        
        model, tokenizer = ran_trainer.train_ran_model(
            output_dir=TRAINING_CONFIG['output_dir']
        )
        
        print("\n" + "=" * 60)
        print("✅ Training completed successfully!")
        print(f"⏱️ Finished at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
        print(f"💾 Model saved to: {TRAINING_CONFIG['output_dir']}")
        
        # Check model files
        model_files = os.listdir(TRAINING_CONFIG['output_dir'])
        print(f"\n📁 Model files created: {len(model_files)}")
        for file in sorted(model_files):
            file_path = os.path.join(TRAINING_CONFIG['output_dir'], file)
            if os.path.isfile(file_path):
                size_mb = os.path.getsize(file_path) / (1024 * 1024)
                print(f"   {file}: {size_mb:.2f} MB")
        
        # Calculate total model size
        total_size_mb = sum(os.path.getsize(os.path.join(TRAINING_CONFIG['output_dir'], f)) 
                           for f in model_files if os.path.isfile(os.path.join(TRAINING_CONFIG['output_dir'], f))) / (1024 * 1024)
        print(f"\n📦 Total model size: {total_size_mb:.2f} MB")
        
        training_successful = True
        
        # Post-training cleanup
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            print("🧹 GPU memory cleared after training")
        
    except Exception as e:
        print(f"\n❌ Training failed: {e}")
        print(f"   Error type: {type(e).__name__}")
        print("\n🛠️ Troubleshooting suggestions:")
        print("   1. Restart the kernel and try again")
        print("   2. Reduce batch_size to 1 in TRAINING_CONFIG")
        print("   3. Set num_epochs to 1 for a quick test")
        print("   4. Close other applications to free memory")
        print("   5. Try CPU-only training by setting CUDA_VISIBLE_DEVICES=''")
        
        training_successful = False
        model, tokenizer = None, None
        
        # Emergency cleanup
        gc.collect()
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
            
else:
    print("❌ Cannot train model without training data")
    print("Please run the training data generation cells first.")
    training_successful = False
    model, tokenizer = None, None
# Out:
# 🚀 Starting Memory-Optimized RAN Domain Model Training
# ⏱️ Started at: 2025-08-08 07:10:02
# 📊 Training on 1180 samples
#
# ⚠️ Note: This uses memory-optimized settings to prevent kernel crashes
# Training may take 15-45 minutes depending on your hardware.
# ============================================================
# 🎯 Training Configuration:
#    Model: distilbert-base-uncased
#    Epochs: 2
#    Batch Size: 2
#    Gradient Accumulation: 4
#    Output: ./ran_domain_model
#
# Compatibility check: Transformers 4.54.1 - fully compatible
# Generating training data...
# 🔍 Extracting real KG data for training...
# 📊 Extracted 10888 real entities from 16 categories
# ✅ Generated 1180 training samples with entities
# Generated 1180 training samples
# Loading base model...
# 📊 Extracted 10888 real entities from 16 categories
# ✅ Generated 1180 training samples with entities
# Generated 1180 training samples
# Loading base model...
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Tokenizing dataset...
# Map: 100%|██████████| 1180/1180 [00:00<00:00, 14242.98 examples/s]
# Starting training...
# 🚀 Starting training with memory optimization...
#     <div>
#
#       <progress value='296' max='296' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [296/296 09:34, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>2.055600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.849100</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.091700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.015200</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.010800</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model to ./ran_domain_model
# Training completed successfully!
#
# ============================================================
# ✅ Training completed successfully!
# ⏱️ Finished at: 2025-08-08 07:19:55
# 💾 Model saved to: ./ran_domain_model
#
# 📁 Model files created: 10
#    config.json: 0.00 MB
#    intent_labels.json: 0.00 MB
#    model.safetensors: 255.45 MB
#    special_tokens_map.json: 0.00 MB
#    tokenizer.json: 0.68 MB
#    tokenizer_config.json: 0.00 MB
#    training_args.bin: 0.01 MB
#    training_info.json: 0.00 MB
#    vocab.txt: 0.22 MB
#
# 📦 Total model size: 256.36 MB
# Training completed successfully!
#
# ============================================================
# ✅ Training completed successfully!
# ⏱️ Finished at: 2025-08-08 07:19:55
# 💾 Model saved to: ./ran_domain_model
#
# 📁 Model files created: 10
#    config.json: 0.00 MB
#    intent_labels.json: 0.00 MB
#    model.safetensors: 255.45 MB
#    special_tokens_map.json: 0.00 MB
#    tokenizer.json: 0.68 MB
#    tokenizer_config.json: 0.00 MB
#    training_args.bin: 0.01 MB
#    training_info.json: 0.00 MB
#    vocab.txt: 0.22 MB
#
# 📦 Total model size: 256.36 MB

# %% [markdown]
# ## 14. Summary and Next Steps

# %%
# Training Process Summary
print("📋 RAN Domain Model Training Summary")
print("=" * 40)

# Check what was completed
completed_steps = []
if neo4j_integrator:
    completed_steps.append("✅ Neo4j connection established")
else:
    completed_steps.append("❌ Neo4j connection failed")

if 'enhanced_training_data' in locals() and enhanced_training_data:
    completed_steps.append(f"✅ Generated {len(enhanced_training_data)} training samples with entities")
else:
    completed_steps.append("❌ Training data generation failed")

if 'training_successful' in locals() and training_successful:
    completed_steps.append("✅ Model training completed successfully")
    completed_steps.append(f"✅ Model saved to {TRAINING_CONFIG['output_dir']}")
else:
    completed_steps.append("❌ Model training failed")

for step in completed_steps:
    print(step)

print("\n🎯 Next Steps:")
if 'training_successful' in locals() and training_successful:
    print("1. ✅ RAN domain model training completed!")
    print("2. ? Run model evaluation using ran_model_evaluation.ipynb")
    print("3. 🚀 Deploy the model in your chatbot application")
    print("4. 📊 Monitor performance in production")
    print("5. 🔄 Retrain periodically with new data")
    
    print(f"\n📁 Model saved at: {TRAINING_CONFIG['output_dir']}")
    print(f"📊 Training samples: {len(enhanced_training_data) if 'enhanced_training_data' in locals() else 'N/A'}")
    
    print("\n? For comprehensive evaluation:")
    print("   👉 Open and run: ran_model_evaluation.ipynb")
    print("   This will test the model performance, accuracy, and integration")
    
    print("\n?💡 Usage in your application:")
    print('```python')
    print('from chatbot import EnhancedRANChatbot')
    print('chatbot = EnhancedRANChatbot(neo4j_integrator, use_domain_model=True)')
    print('result = chatbot.enhanced_process_query("your query here")')
    print('```')
else:
    print("1. ❓ Review any errors above")
    print("2. 🔧 Check memory configuration if kernel crashed")
    print("3. 🔄 Try reducing batch_size in TRAINING_CONFIG")
    print("4. 💻 Consider CPU-only training for memory-constrained systems")
    print("5. ? Re-run the training process")

print(f"\n⏰ Training completed at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

# Memory cleanup after training
import gc
gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("🧹 GPU memory cleaned up")

# %% [markdown]
# ## 15. Additional Resources and Tips

# %%
# Additional tips and resources
print("💡 Tips for Production Use")
print("=" * 30)
print()
print("🚀 Performance Optimization:")
print("   • Use GPU for faster inference")
print("   • Implement model caching for repeated queries")
print("   • Consider model quantization for smaller size")
print()
print("📊 Model Monitoring:")
print("   • Track prediction confidence scores")
print("   • Monitor query types and patterns")
print("   • Collect user feedback for retraining")
print()
print("🔄 Continuous Improvement:")
print("   • Regularly retrain with new data")
print("   • Expand training data with real user queries")
print("   • Fine-tune hyperparameters based on performance")
print()
print("🛠️ Troubleshooting:")
print("   • Low confidence predictions: Add more training data")
print("   • Memory issues: Reduce batch size or model size")
print("   • Slow training: Use GPU or reduce data size")
print()
print("📚 Documentation:")
print("   • Transformers: https://huggingface.co/docs/transformers")
print("   • Datasets: https://huggingface.co/docs/datasets")
print("   • Neo4j Python: https://neo4j.com/docs/python-manual")
print()
print("🎯 For questions or support:")
print("   • Check the README.md in the chatbot_module")
print("   • Review the example code in chatbot_example.py")
print("   • Consult the enhanced chatbot documentation")
